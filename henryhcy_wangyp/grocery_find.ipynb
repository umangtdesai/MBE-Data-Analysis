# %%
import urllib.request
import json
import dml
import prov.model
import datetime
import uuid
import csv 
import io
import time

# %%
key = dml.auth['services']['googleprotocal']['key']
bos_loc = "42.3600825,-71.0588801"
prefix = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
_type = 'supermarket'
radius = '50000'

url = prefix +'location='+bos_loc+"&radius="+radius+"&type="+_type+"&key="+key

response = urllib.request.urlopen(url).read().decode("utf-8")
r = json.loads(response)

# %%
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIgEAAK6LVWJY5j1pAFQBV_aBZaaBfHnzVx9Txbnem8w4rR8K4H0MwAs3zBeIjddVd3Y9d1PnednujKeB_uglYxcSQhJ9-oKgN2UAxCXsHBCt46NoSWEWfi2E25V6mGSN5sHpfdyPip511kXapD5joaBCxR0Df7HU_Hbd_3g_I6WOC9DnxSxsHk86-3Cx0V7uJfr-Vszhhu1j_D6oXI7vWhWUyoRiAUxZOXE3HhgwJ0Td_-SJaLdVYnpGh2OkrKEl2fT1hxLQ4X90QSCztrXMwCIwqtdf92nLm7bctKGlaliSb45IbqkxQXl6k6umULDqwx29eU4DxEYo5fn0QaM1qU5SKz0qTobzMxUkhg7Og9GO5B1ffJnFtktoSKixzffdCNfCmJyGqy9hcXgrcrVmeOs71vsSEG8hCXeNdHrE0HNxWgOeMZgaFKJmfs7dNa1XMusLBlOIQvvY7ChO',
#  'results': [{'geometry': {'location': {'lat': 42.362046,
#      'lng': -71.06552669999999},
#     'viewport': {'northeast': {'lat': 42.3631687802915,
#       'lng': -71.0639358197085},
#      'southwest': {'lat': 42.3604708197085, 'lng': -71.06663378029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '828798bb2245076b455b0d73af7485fcc8318787',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113815392849087130851/photos">G Aquino</a>'],
#      'photo_reference': 'CmRaAAAA4aGn7FGayoclqOq_gkWS07cQqSkYelacBige5HMdFg_eJ_Yl4SeWhiFl4bZ5XOYO_fc1qcpz2g3cBVUPkxkvow-XvjQXzLkymWr4p_JqWMYQAhBCre99TwuW1aELMSSyEhC0GfD1S1uMa0qLFxtxLujuGhSVuyZv2X6td17SGU0RE-KFF2COxg',
#      'width': 3264}],
#    'place_id': 'ChIJR-k8aJpw44kRJw6nYpXdRow',
#    'plus_code': {'compound_code': '9W6M+RQ Boston, Massachusetts, United States',
#     'global_code': '87JC9W6M+RQ'},
#    'price_level': 3,
#    'rating': 4.1,
#    'reference': 'ChIJR-k8aJpw44kRJw6nYpXdRow',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'store',
#     'health',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 447,
#    'vicinity': '181 Cambridge Street, Boston'},
#   {'geometry': {'location': {'lat': 42.3438262, 'lng': -71.0873163},
#     'viewport': {'northeast': {'lat': 42.3451584802915,
#       'lng': -71.0857781197085},
#      'southwest': {'lat': 42.3424605197085, 'lng': -71.08847608029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '09905d1e1ad9e1899736b7adfc01e2d21af08618',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106656757212598532235/photos">Andie Smidler</a>'],
#      'photo_reference': 'CmRaAAAAxEUxTHnLcdYqF6dkqvjZpujMpTWjzfKbtLa2tpIOzeBLDi9iBNqIkhG9qqFaP4ZBOhGNZxiHeZoRymUhC_LQsUEg0vxchyfsd6S_-OT-RIm5ehTuc02CaZdlN2KUqgi1EhA86JQtnBnkYk3_2KvkTybZGhRuP5X5FyCd2XvXNMd2ghqyTCxZeg',
#      'width': 4032}],
#    'place_id': 'ChIJJYdkPBp644kRwWFG-QDpyuY',
#    'plus_code': {'compound_code': '8WV7+G3 Boston, Massachusetts, United States',
#     'global_code': '87JC8WV7+G3'},
#    'price_level': 3,
#    'rating': 4.2,
#    'reference': 'ChIJJYdkPBp644kRwWFG-QDpyuY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'store',
#     'health',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 670,
#    'vicinity': '15 Westland Avenue, Boston'},
#   {'geometry': {'location': {'lat': 42.36789829999999, 'lng': -71.1021683},
#     'viewport': {'northeast': {'lat': 42.3692343302915,
#       'lng': -71.10084776970851},
#      'southwest': {'lat': 42.3665363697085, 'lng': -71.10354573029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '3e0324d5a63b4da2c740e41815d0732c59a27f60',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104898819944919977652/photos">Amelia</a>'],
#      'photo_reference': 'CmRaAAAAZ9SDVmBRaL4QjN-pRvJ-iPd84HJkhsUH-kJ9ZqilX0nbMd1LmhTjUgvyViaRoW4nvrYPCLFaZxGrdz95JRf1bKNsNwdA9jo4_PbOAfQ91QHSfVvxmmdCrC39ASc_0dsNEhC_AV3ei-6iQo2MQXe4lD4fGhTMeVwqpO64RK1rEbpICKEuyrgU2w',
#      'width': 4160}],
#    'place_id': 'ChIJmzrVPVJ344kRAySZVMsT_dQ',
#    'plus_code': {'compound_code': '9V9X+54 Cambridge, Massachusetts, United States',
#     'global_code': '87JC9V9X+54'},
#    'price_level': 3,
#    'rating': 4.1,
#    'reference': 'ChIJmzrVPVJ344kRAySZVMsT_dQ',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'store',
#     'health',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 449,
#    'vicinity': '115 Prospect Street, Cambridge'},
#   {'geometry': {'location': {'lat': 42.36100709999999, 'lng': -71.1139362},
#     'viewport': {'northeast': {'lat': 42.3624402302915,
#       'lng': -71.1127315197085},
#      'southwest': {'lat': 42.35974226970851, 'lng': -71.11542948029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'fb7a383dd58e8e0cd5dcb14eab16bb7c96539560',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101445918540405765895/photos">謝小娟</a>'],
#      'photo_reference': 'CmRaAAAAmqsp4uxJWpFStUJ7BhbqeGcsy8L1SCbT4xKTRjVMNq02fkJteSC5TDZx5dICZPXSxFsjZ9Fu4LVky39HnSzmoOD2tgjCq3XFuhNVovL0N9yHqgRDS5WrdAC694JgXHYIEhC2YhlY2DPe0O03h-ldKVZ2GhSbLKpef3d-6EXZkIbodAEMnQynGw',
#      'width': 4032}],
#    'place_id': 'ChIJieJNoVh344kRnMrYGkna3mo',
#    'plus_code': {'compound_code': '9V6P+CC Cambridge, Massachusetts, United States',
#     'global_code': '87JC9V6P+CC'},
#    'price_level': 3,
#    'rating': 4.3,
#    'reference': 'ChIJieJNoVh344kRnMrYGkna3mo',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'store',
#     'health',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 596,
#    'vicinity': '340 River Street, Cambridge'},
#   {'geometry': {'location': {'lat': 42.3964821, 'lng': -71.0423237},
#     'viewport': {'northeast': {'lat': 42.3975690802915,
#       'lng': -71.04122281970848},
#      'southwest': {'lat': 42.3948711197085, 'lng': -71.0439207802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '94e4068d984f13ff6f8d730fa1ca00151c9a629a',
#    'name': 'Market Basket',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115734875353621771246/photos">M S</a>'],
#      'photo_reference': 'CmRZAAAASpZbuip_StuacX8WoQpivvj8RCtMewaGO6jEbeOz8pc6s_eJk0Zl7h6Y5WWn8Lm73Go7W3B5nqTIU4xCZ8hKK4HQQm3ePjLWSwrHSkQDqgpDXdGEzBovX4dLGquJ9QJVEhDTXU1V89iQCW1RGlveFO3QGhT8_EPKxAOhM0yMj2cOCPl2IBOjRA',
#      'width': 4032}],
#    'place_id': 'ChIJ5fTzg69x44kRpMmXJIowALs',
#    'plus_code': {'compound_code': '9XW5+H3 Chelsea, Massachusetts, United States',
#     'global_code': '87JC9XW5+H3'},
#    'rating': 4.4,
#    'reference': 'ChIJ5fTzg69x44kRpMmXJIowALs',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'store',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 1687,
#    'vicinity': '170 Everett Avenue, Chelsea'},
#   {'geometry': {'location': {'lat': 42.3484566, 'lng': -71.0840861},
#     'viewport': {'northeast': {'lat': 42.3497226802915,
#       'lng': -71.08269596970848},
#      'southwest': {'lat': 42.3470247197085, 'lng': -71.08539393029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '1d7ee129f8f291b16a72d3eaccbcc94e2be4af2f',
#    'name': "Trader Joe's",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110923422641888927618/photos">Deanna L</a>'],
#      'photo_reference': 'CmRaAAAAqBsMxBfgnscURaExAuelBPgtlaD6PhDcxCBEF8cq08IjHm8gQBoQ10camXvnzsPhUSEiXsu_befvmcaPAkIzS4uBBaYmeEvmmGPNAcLyx40hmo2dtD7mv7lAurVz7oTUEhAqvACbeyYr1bhxtirEZVyzGhSOzzEEyxB22c9-qszkSGbuVZZEeg',
#      'width': 3264}],
#    'place_id': 'ChIJCzw8lQ9644kRBRl50ukidH4',
#    'plus_code': {'compound_code': '8WX8+99 Boston, Massachusetts, United States',
#     'global_code': '87JC8WX8+99'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJCzw8lQ9644kRBRl50ukidH4',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'florist',
#     'supermarket',
#     'store',
#     'health',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 922,
#    'vicinity': '899 Boylston Street, Boston'},
#   {'geometry': {'location': {'lat': 42.3807302, 'lng': -71.1015968},
#     'viewport': {'northeast': {'lat': 42.3822425302915,
#       'lng': -71.10015721970849},
#      'southwest': {'lat': 42.3795445697085, 'lng': -71.10285518029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'f584e914fe6a34594c840c66aac0f8fecf44a271',
#    'name': 'Market Basket',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2309,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111704714362262488449/photos">Alfredo Pina</a>'],
#      'photo_reference': 'CmRaAAAA2G-VgOC4_Z78RgSraKq7ZWOjTsg8lVwhGcPsNkmY72IYLiQl2WjSkCf1EycBS6eEj4lVx_zfOBj0cvtIHswnOp5Wb5xEgN4qH2TgkdFdrgU64MHXxQoCIueaeFgRp2pOEhBxq9HLFxRMIdIAHJ5r6Bk5GhSJZazVbQgxs2cxU0jo5Iobu5RMIA',
#      'width': 3694}],
#    'place_id': 'ChIJ296XtDV344kRXTFzOH4n2Vg',
#    'plus_code': {'compound_code': '9VJX+79 Somerville, Massachusetts, United States',
#     'global_code': '87JC9VJX+79'},
#    'rating': 4.3,
#    'reference': 'ChIJ296XtDV344kRXTFzOH4n2Vg',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'store',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 2425,
#    'vicinity': '400 Somerville Avenue, Somerville'},
#   {'geometry': {'location': {'lat': 42.3582624, 'lng': -71.1141683},
#     'viewport': {'northeast': {'lat': 42.3594879302915,
#       'lng': -71.11285866970849},
#      'southwest': {'lat': 42.3567899697085, 'lng': -71.11555663029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '5a282a1170f8e3d63c261e82edf1bce563e21fa4',
#    'name': "Trader Joe's",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108953816296402134567/photos">Shalev NessAiver</a>'],
#      'photo_reference': 'CmRaAAAA3OCVs8FU-nFm2HpEqiPeq3oIYViEyPA9T_EMBggQlHwjJNnfsY7nVVkeO3rxJVj-A4hAknrR9K6nKrSR3zQCq6VCk6VcD5xYBg5NAmpwhHBI8TTTzvmNaxcn17nRHEVHEhBRUvR2pDXHd00_hET19aKZGhTVqb5PNTrDIomJViU_8whtbV5JIA',
#      'width': 1920}],
#    'place_id': 'ChIJ5-fc6ON544kRTnuRYf2PDD4',
#    'plus_code': {'compound_code': '9V5P+88 Cambridge, Massachusetts, United States',
#     'global_code': '87JC9V5P+88'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJ5-fc6ON544kRTnuRYf2PDD4',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'florist',
#     'supermarket',
#     'store',
#     'health',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 744,
#    'vicinity': '748 Memorial Drive, Cambridge'},
#   {'geometry': {'location': {'lat': 42.3755356, 'lng': -71.0661184},
#     'viewport': {'northeast': {'lat': 42.37691640000001, 'lng': -71.0633478},
#      'southwest': {'lat': 42.3738616, 'lng': -71.06871659999999}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '42593c3a70357131e707168403befcdb6cd948be',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3038,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103883897278594082398/photos">Hai Cao</a>'],
#      'photo_reference': 'CmRaAAAAafb-YvWeMOdGfS0AS4z--XbHEh0awz0r17VZ1sY4vj2IIRKFqdcImka2o_nVXfkZtCxLsGZNFXMrdQ2pkoUTmzy8kUqisuxRQ6ZBWBktJut0UXU72A-5GzmZORfZvFF9EhDtKPwp8OjYG5LGMu4nUX-YGhSpQLprhjKyehKSLbFA0PuhhQFISg',
#      'width': 4050}],
#    'place_id': 'ChIJZziLZ-xw44kRp8J-N9vM53Y',
#    'plus_code': {'compound_code': '9WGM+6H Boston, Massachusetts, United States',
#     'global_code': '87JC9WGM+6H'},
#    'price_level': 3,
#    'rating': 4.3,
#    'reference': 'ChIJZziLZ-xw44kRp8J-N9vM53Y',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'store',
#     'health',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 496,
#    'vicinity': '51 Austin Street, Charlestown'},
#   {'geometry': {'location': {'lat': 42.3758659, 'lng': -71.1032516},
#     'viewport': {'northeast': {'lat': 42.3772374802915,
#       'lng': -71.1016960197085},
#      'southwest': {'lat': 42.3745395197085, 'lng': -71.1043939802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '3e340280681b205f004cdd89dc7eac84fca46f2b',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115832882436993992452/photos">Sheraz Choudhary</a>'],
#      'photo_reference': 'CmRaAAAA9PV-l5ZCEJgnuWzrJWAdpgp2neq8RpQRIIx84mDiqIhVmzGK9F7AQjwf6Dg7gLP-pHCxbVsVb3WsKFpA9MbY2F4ap05jIFizpNokDTmbu91JL6qXNj-D4UHsanDpZRrhEhBKNPOnR7QccFRTy8v81bSDGhToc6OIYNss291_tJmip3pyEbExHA',
#      'width': 4032}],
#    'place_id': 'ChIJj7oq2Et344kRnb1BcIMee-Y',
#    'plus_code': {'compound_code': '9VGW+8M Somerville, Massachusetts, United States',
#     'global_code': '87JC9VGW+8M'},
#    'price_level': 3,
#    'rating': 4.2,
#    'reference': 'ChIJj7oq2Et344kRnb1BcIMee-Y',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'store',
#     'health',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 389,
#    'vicinity': '45 Beacon Street, Somerville'},
#   {'geometry': {'location': {'lat': 42.3463576, 'lng': -71.0650258},
#     'viewport': {'northeast': {'lat': 42.34773543029149,
#       'lng': -71.0637804197085},
#      'southwest': {'lat': 42.34503746970849, 'lng': -71.0664783802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'c7a2d2696fba3ebd0ce44a3c838829f0545980a3',
#    'name': 'C-Mart Supermarket',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105209365503839609989/photos">Iori Ng</a>'],
#      'photo_reference': 'CmRaAAAAOxuPs_htl75wrP0v8zkZMqpni4S7JJsIJLd4ahuaYFMv_7hw7cURkDHaXOfO7ODmCb0sfJe76tZ3PEUW_Rw_2YmazTmZBLsIulpoXP_sc79GLF6mu4gYlM4fpi9DlSmaEhAhUv25Z65XyvVZLZELPlDpGhSZK-j8qXzPBDcKVYSe-jyEkZkTDA',
#      'width': 3024}],
#    'place_id': 'ChIJzwcTqXF644kRnLFDPZEwxTQ',
#    'plus_code': {'compound_code': '8WWM+GX Boston, Massachusetts, United States',
#     'global_code': '87JC8WWM+GX'},
#    'rating': 3.9,
#    'reference': 'ChIJzwcTqXF644kRnLFDPZEwxTQ',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'store',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 412,
#    'vicinity': '50 Herald Street, Boston'},
#   {'geometry': {'location': {'lat': 42.346179, 'lng': -71.10826569999999},
#     'viewport': {'northeast': {'lat': 42.3476203802915,
#       'lng': -71.10700441970847},
#      'southwest': {'lat': 42.3449224197085, 'lng': -71.1097023802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '3105aadea009fd4a269d886f491492888936b061',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106656757212598532235/photos">Andie Smidler</a>'],
#      'photo_reference': 'CmRaAAAAFuX3P9Vc3hoQj_L_P71gIt7tN5W-kbGii-gHBLd7bUtc6t45N9kmrgd-uqWFslz0uyEy8r97xixc-Cjl3ngljXl3_3WM9m-Kt8w0kuSvTWbZHloLoXZXbqivsCX3pCdyEhCmukQk_7r3yCOVxWEhlt4mGhTKNtFjNVJIZmWaXIWwjyk0POPOsg',
#      'width': 4032}],
#    'place_id': 'ChIJz7UWGvJ544kROfCqT14Q5Q0',
#    'plus_code': {'compound_code': '8VWR+FM Brookline, Massachusetts, United States',
#     'global_code': '87JC8VWR+FM'},
#    'price_level': 3,
#    'rating': 4.1,
#    'reference': 'ChIJz7UWGvJ544kROfCqT14Q5Q0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'store',
#     'health',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 283,
#    'vicinity': '1028 Beacon Street, Brookline'},
#   {'geometry': {'location': {'lat': 42.3356862, 'lng': -71.0465964},
#     'viewport': {'northeast': {'lat': 42.3371448802915,
#       'lng': -71.04511801970848},
#      'southwest': {'lat': 42.3344469197085, 'lng': -71.0478159802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'cf4ac172d38a1c7f6bafd24803adac9728f09ac4',
#    'name': 'Family Dollar',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3984,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111501389028268190125/photos">John Burke</a>'],
#      'photo_reference': 'CmRaAAAAfPs4Sqhutg13PM10Hy8cNrHYba3g1XookHgpNu8ZfRw11eotaVPTOyb5favX81V7cSboeEDO3JXx1ahnbBFsRId-DhSPzCLJEkfYwW-1kXOeEGJV0bD3WE0KmYAqZTDwEhAYaFWvn5Op1vYTfaDqfgY9GhQ5P6c8L0FAh-dNQmKkQhtUInmPAA',
#      'width': 2988}],
#    'place_id': 'ChIJtYif1ot644kRm24Yw-KOBoA',
#    'plus_code': {'compound_code': '8XP3+79 Boston, Massachusetts, United States',
#     'global_code': '87JC8XP3+79'},
#    'price_level': 1,
#    'rating': 4.1,
#    'reference': 'ChIJtYif1ot644kRm24Yw-KOBoA',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'clothing_store',
#     'store',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 70,
#    'vicinity': '459 West Broadway, Boston'},
#   {'geometry': {'location': {'lat': 42.3442158, 'lng': -71.0656443},
#     'viewport': {'northeast': {'lat': 42.3455903802915,
#       'lng': -71.0643675197085},
#      'southwest': {'lat': 42.3428924197085, 'lng': -71.0670654802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'b241445e9db6b0298589078b0e26968309628307',
#    'name': "Ming's Supermarket",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113631667309182153889/photos">Andy Zhang</a>'],
#      'photo_reference': 'CmRaAAAA7ti_epeHpEjHVHJo-qFXYuRN1oSONvNsbRv7CE_Q1O1pGscEKOqAUeQ-Nb9UiZJ5-QyO8Ykoca8wvsImNiHpUoYEAvbW4DdmBaiG4La0DSilqLAg3yfaugU4Q7J0w9MhEhBMresxzhqI3a97EnVlGJpHGhSfiIFXQklPyE8zGV6zOTLBNSNthw',
#      'width': 4032}],
#    'place_id': 'ChIJs8yo23F644kRScIIr53rSt0',
#    'plus_code': {'compound_code': '8WVM+MP Boston, Massachusetts, United States',
#     'global_code': '87JC8WVM+MP'},
#    'rating': 4.1,
#    'reference': 'ChIJs8yo23F644kRScIIr53rSt0',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'store',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 414,
#    'vicinity': '1102 Washington Street, Boston'},
#   {'geometry': {'location': {'lat': 42.31957999999999,
#      'lng': -71.08250559999999},
#     'viewport': {'northeast': {'lat': 42.32096673029149,
#       'lng': -71.08112581970848},
#      'southwest': {'lat': 42.31826876970849, 'lng': -71.0838237802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '1ddcacd4ffae603784ebb2cd08aae82ea047a192',
#    'name': 'Save-A-Lot',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 670,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111130164504616486454/photos">Save-A-Lot</a>'],
#      'photo_reference': 'CmRaAAAA1xeK8H5snSdCNuUpdMRNMPBjsJfhj944j5c1lneOYmvCHp9I4FWSqfXUYRTCkTX7hdncRAvnXaJ9cfM4iZixMdr0QGIHTr9qV-XUbI_FKw9NfRFz9Ho2DSBl-eu54gVXEhBzFKQcqu3gaGIFN7FzW5I-GhR_935Rbf_pavhO5KAcquqAjshG0Q',
#      'width': 1191}],
#    'place_id': 'ChIJmdT51jJ644kRv_NGJQQtlYc',
#    'plus_code': {'compound_code': '8W98+RX Boston, Massachusetts, United States',
#     'global_code': '87JC8W98+RX'},
#    'price_level': 1,
#    'rating': 4.1,
#    'reference': 'ChIJmdT51jJ644kRv_NGJQQtlYc',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'store',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 191,
#    'vicinity': '330 Martin Luther King Jr Boulevard, Roxbury'},
#   {'geometry': {'location': {'lat': 42.3410166, 'lng': -71.0706596},
#     'viewport': {'northeast': {'lat': 42.34230498029149,
#       'lng': -71.0692399697085},
#      'southwest': {'lat': 42.3396070197085, 'lng': -71.07193793029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '2b1a50a5aca68be8ebb2b3bdabe7c669a1d51095',
#    'name': "Foodie's Markets",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 505,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102108040919447770613/photos">Foodie&#39;s Markets</a>'],
#      'photo_reference': 'CmRaAAAAF1nbb9RzbI7QBxWMFKGWWitzX6lgnefrStaaiT3P1ddmztXZSgHHQBaz1yZV6XYG2Lrhd12_909teKi47NnLDp-3KztEQPM9s88iP46oPpEv_3eb3QWghrQiqw9mtUl_EhD8960j2JmReg6OubaJTqHLGhRdBfQJlFiarZlNwzCQq3zCP04nEA',
#      'width': 720}],
#    'place_id': 'ChIJNWrXHo6E44kRKVQwkCd7T5Y',
#    'plus_code': {'compound_code': '8WRH+CP Boston, Massachusetts, United States',
#     'global_code': '87JC8WRH+CP'},
#    'rating': 4.1,
#    'reference': 'ChIJNWrXHo6E44kRKVQwkCd7T5Y',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'store',
#     'health',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 306,
#    'vicinity': '1421 Washington Street, Boston'},
#   {'geometry': {'location': {'lat': 42.3627302, 'lng': -71.0584097},
#     'viewport': {'northeast': {'lat': 42.36424068029149,
#       'lng': -71.05689276970848},
#      'southwest': {'lat': 42.3615427197085, 'lng': -71.0595907302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '6af3063cfd3a1acab08928d482e4bea52cf1f627',
#    'name': 'Beyenes Food Basket',
#    'photos': [{'height': 3968,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100112498606072305593/photos">Hamza Malik</a>'],
#      'photo_reference': 'CmRaAAAAwUUdleeDgZsR-nl-EtzifmAu3exRyCaiKEOThv7G8w4CRln3_pzxTHGuh73i6tespQ_rNn_ay0ydYS2aFgNfYV5y_S6X1a3DshqHeMYoL1_L8-ToSnMnOeAxYjXxJNByEhCX4cdEbKnaF8ByUpeP9RQwGhRIyLvd7mz8exKtIAhsndOuoq56mw',
#      'width': 2976}],
#    'place_id': 'ChIJLamEdo9w44kRvjhzaWYMlwM',
#    'plus_code': {'compound_code': '9W7R+3J Boston, Massachusetts, United States',
#     'global_code': '87JC9W7R+3J'},
#    'rating': 3,
#    'reference': 'ChIJLamEdo9w44kRvjhzaWYMlwM',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'store',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': '1 Congress Street, Boston'},
#   {'geometry': {'location': {'lat': 42.391881, 'lng': -71.034258},
#     'viewport': {'northeast': {'lat': 42.3932708802915,
#       'lng': -71.0330394197085},
#      'southwest': {'lat': 42.3905729197085, 'lng': -71.03573738029152}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': 'cf800180cd7bd18f37b6b37dca496c053342feb4',
#    'name': 'Stop and Compare Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110552770493386291935/photos">Noe Vladymyr</a>'],
#      'photo_reference': 'CmRZAAAAy0UBtEd6XG5NCJvVGgiWhpnUlQ6WKaPHhGeRrka318c9aMWusTlcWkG1O1YXwmFV-XBv19Ip5Y-0vUo9xtloSz7y2sCuQk-CruddgCbTVfD0emkxhWxiZtLdr7dA0QHcEhCWLHFKuC7zJyki-vHAnKF5GhQafxwAdz5hg3cHF-VDCqG2OG2zVg',
#      'width': 4032}],
#    'place_id': 'ChIJddPecrFx44kRY_uGmb2I-7Q',
#    'plus_code': {'compound_code': '9XR8+Q7 Chelsea, Massachusetts, United States',
#     'global_code': '87JC9XR8+Q7'},
#    'rating': 4.1,
#    'reference': 'ChIJddPecrFx44kRY_uGmb2I-7Q',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'store',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 249,
#    'vicinity': '153 Hawthorne Street, Chelsea'},
#   {'geometry': {'location': {'lat': 42.37528340000001, 'lng': -71.0381029},
#     'viewport': {'northeast': {'lat': 42.3765941802915,
#       'lng': -71.0367274197085},
#      'southwest': {'lat': 42.37389621970851, 'lng': -71.0394253802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '96a64ef360bfe280f536347cf6b6d1e0007abd50',
#    'name': 'Family Dollar',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115049323380923574849/photos">Carlos Gabriel Medina Gonzalez</a>'],
#      'photo_reference': 'CmRaAAAAthMdUvNl-8wG4TkOHyT8nySYcz4YK01miSp-TRXfXDevHflqJkplfJJ4CuVht6NzgnVrzHtKpHvwH9o0Y1e5qdtkWVIf7KpU6YUivJkYXY6V8ELefhHS775Z9v3gSUjAEhDauggJATp-VNJqHv2fdQn_GhRN8TNPvNSix49zXKvYd6U4g5D4Yw',
#      'width': 3096}],
#    'place_id': 'ChIJkTR61Fpw44kR9RhKnnBLpj8',
#    'plus_code': {'compound_code': '9XG6+4Q Boston, Massachusetts, United States',
#     'global_code': '87JC9XG6+4Q'},
#    'price_level': 1,
#    'rating': 4,
#    'reference': 'ChIJkTR61Fpw44kR9RhKnnBLpj8',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'clothing_store',
#     'store',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 92,
#    'vicinity': '22 Bennington Street, East Boston'},
#   {'geometry': {'location': {'lat': 42.3811686, 'lng': -71.10195449999999},
#     'viewport': {'northeast': {'lat': 42.3825074302915,
#       'lng': -71.1005685197085},
#      'southwest': {'lat': 42.3798094697085, 'lng': -71.10326648029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '9c192abdaf518842870e550a294ad1798f865219',
#    'name': 'Little India',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114955075604875730298/photos">Ankit</a>'],
#      'photo_reference': 'CmRaAAAABoYZhLkLToizB4ZzF2k4xZTf-ok7h7_gWE8b3Y1MP_8ASog5-qa716qZSZswgWW9XTLCtXekV2MB9LUnmtQYDt-uHuhRX1yP7Bw2UfPJw44sO-ZjbdZS73D8CsjgQ2-MEhCevZIaBTV7qruVYHPzkjjBGhTr5EVhRy1rXJpu8Mlg3OCqJLbzYA',
#      'width': 4640}],
#    'place_id': 'ChIJg_xeyzV344kRgWyxN_BbVns',
#    'plus_code': {'compound_code': '9VJX+F6 Somerville, Massachusetts, United States',
#     'global_code': '87JC9VJX+F6'},
#    'rating': 3.9,
#    'reference': 'ChIJg_xeyzV344kRgWyxN_BbVns',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'store',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 149,
#    'vicinity': '438 Somerville Avenue, Somerville'}],
#  'status': 'OK'}

# %%
data = []
data.append(r['results'])
nextpg = r['next_page_token']
nextpg
# Out:
# 'CrQCIgEAAK6LVWJY5j1pAFQBV_aBZaaBfHnzVx9Txbnem8w4rR8K4H0MwAs3zBeIjddVd3Y9d1PnednujKeB_uglYxcSQhJ9-oKgN2UAxCXsHBCt46NoSWEWfi2E25V6mGSN5sHpfdyPip511kXapD5joaBCxR0Df7HU_Hbd_3g_I6WOC9DnxSxsHk86-3Cx0V7uJfr-Vszhhu1j_D6oXI7vWhWUyoRiAUxZOXE3HhgwJ0Td_-SJaLdVYnpGh2OkrKEl2fT1hxLQ4X90QSCztrXMwCIwqtdf92nLm7bctKGlaliSb45IbqkxQXl6k6umULDqwx29eU4DxEYo5fn0QaM1qU5SKz0qTobzMxUkhg7Og9GO5B1ffJnFtktoSKixzffdCNfCmJyGqy9hcXgrcrVmeOs71vsSEG8hCXeNdHrE0HNxWgOeMZgaFKJmfs7dNa1XMusLBlOIQvvY7ChO'

# %%
url = prefix+"pagetoken="+nextpg+"&key="+key
response = urllib.request.urlopen(url).read().decode("utf-8")
r1 = json.loads(response)

# %%
nextpg1=r1['next_page_token']
url = prefix+"pagetoken="+nextpg1+"&key="+key
response = urllib.request.urlopen(url).read().decode("utf-8")
r2= json.loads(response)
for i in r2['results']:
    print(i['name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-d9e8cdc480aa> in <module>()
# ----> 1 nextpg1=r1['next_page_token']
#       2 url = prefix+"pagetoken="+nextpg1+"&key="+key
#       3 response = urllib.request.urlopen(url).read().decode("utf-8")
#       4 r2= json.loads(response)
#       5 for i in r2['results']:
#
# KeyError: 'next_page_token'

# %%
'next_page_token' in r2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b5a9238ad809> in <module>()
# ----> 1 'next_page_token' in r2
#
# NameError: name 'r2' is not defined

# %%
key = dml.auth['services']['googleprotocal']['key']
bos_loc = "42.3600825,-71.0588801"
prefix = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
_type = 'supermarket'
radius = '500000'
next_pg_token = []
data = []

url = prefix +'location='+bos_loc+"&radius="+radius+"&type="+_type+"&key="+key
response = urllib.request.urlopen(url).read().decode("utf-8")
r = json.loads(response)
count = 0

while ('next_page_token' in r):
    count += 1
    print(count)
    nextpg=r['next_page_token']
    
    data = data + (r['results'])
    
    url = prefix+"pagetoken="+nextpg+"&key="+key
    
    response = urllib.request.urlopen(url).read().decode()
    r = json.loads(response)
    while (r['status'] == 'INVALID_REQUEST'):
        time.sleep(.300)
        response = urllib.request.urlopen(url).read().decode()
        r = json.loads(response)
data = data + r['results']
for i in data:
    print(i['name'])
# Out:
# 1
# 2
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Whole Foods Market
# Walmart
# Trader Joe's
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart
# Walmart Supercenter
# Market Basket
# Walmart
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Walmart
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Walmart
# Market Basket
# Roche Bros. Natick

# %%
r['results']
# Out:
# [{'geometry': {'location': {'lat': 42.3409891, 'lng': -71.1265662},
#    'viewport': {'northeast': {'lat': 42.3422990802915,
#      'lng': -71.12519471970849},
#     'southwest': {'lat': 42.3396011197085, 'lng': -71.1278926802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '8988ac2a61e20800fafd2a0eeef6246403f85857',
#   'name': 'Bazaar On Beacon Street',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100306156533413733212/photos">Jennifer Copley</a>'],
#     'photo_reference': 'CmRaAAAA2icOkDCorPat4X7SkSJht4BSImPyfxQ4PeHpoVKLFTljuL0cMMGj5bIOvB9CUPtWv6Oj8wPIaa5FGqDNsQlYPTnqEp14KItZjEQLZwJXMxf4MYIIDJQIs-kaCbOOGsBAEhBtrB3Gc2Z226wODa49HIjqGhTkN4hFZIsdqtjzOfSNm7ItSHD1Ww',
#     'width': 5312}],
#   'place_id': 'ChIJG_jG689544kRaLQvfsOGnK0',
#   'plus_code': {'compound_code': '8VRF+99 Brookline, Massachusetts, United States',
#    'global_code': '87JC8VRF+99'},
#   'rating': 4.5,
#   'reference': 'ChIJG_jG689544kRaLQvfsOGnK0',
#   'scope': 'GOOGLE',
#   'types': ['supermarket',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 229,
#   'vicinity': '1432 Beacon Street, Brookline'},
#  {'geometry': {'location': {'lat': 42.580245, 'lng': -71.288552},
#    'viewport': {'northeast': {'lat': 42.5817010802915,
#      'lng': -71.2873153697085},
#     'southwest': {'lat': 42.5790031197085, 'lng': -71.2900133302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '9a233090a15989781d49628bc544ed69533cf5de',
#   'name': 'Market Basket',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107933583921839046489/photos">anonimous chicka</a>'],
#     'photo_reference': 'CmRaAAAAog8e5Bfd5lUnpDr_k_RHXtty4GcqHhuRB2spWZaEWHk-vsqqV76D57af8WpsKp6g7CPh_6lSqtAFyviQXE0RWGmhAMH10bRaOmD8DLr_OeN_Xj5G_glzHJalWyXLciKdEhC2SmmB_xvpc3bUgLgIShqhGhS8-Oi0viQbpG_e51Ssn_uj6rM2gw',
#     'width': 4048}],
#   'place_id': 'ChIJk6hlxiqi44kR4a1a8xy2kPo',
#   'plus_code': {'compound_code': 'HPJ6+3H Billerica, Massachusetts, United States',
#    'global_code': '87JCHPJ6+3H'},
#   'rating': 4.3,
#   'reference': 'ChIJk6hlxiqi44kR4a1a8xy2kPo',
#   'scope': 'GOOGLE',
#   'types': ['supermarket',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 272,
#   'vicinity': '199 Boston Road, North Billerica'},
#  {'geometry': {'location': {'lat': 42.4170313, 'lng': -71.1265626},
#    'viewport': {'northeast': {'lat': 42.4183905802915,
#      'lng': -71.1250186697085},
#     'southwest': {'lat': 42.4156926197085, 'lng': -71.1277166302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '15e0b02b73db8c8d1f44d8037c68c7272093bd1f',
#   'name': 'Whole Foods Market',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4048,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111293475741697316443/photos">Amanda Cuoco</a>'],
#     'photo_reference': 'CmRaAAAA76O21Zhdc9nC_6SN_4_tJckvLAtsbD8SXbReR4lPdFiZfUaesYmkKIkii70CSULpmfsTLVK_FUm3-NDZkv0Mi_tFm-vPKby5O4kOEA11JZIshsPXG_dJxhU9ZFthJDXJEhAUhFt72s6ELWhNXHaO0zukGhRZYz5En41hn28UPIoLNgci-f7Kvw',
#     'width': 3036}],
#   'place_id': 'ChIJUWka9et244kRcXcyZkGA1mo',
#   'plus_code': {'compound_code': 'CV8F+R9 Medford, Massachusetts, United States',
#    'global_code': '87JCCV8F+R9'},
#   'price_level': 3,
#   'rating': 4.3,
#   'reference': 'ChIJUWka9et244kRcXcyZkGA1mo',
#   'scope': 'GOOGLE',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 451,
#   'vicinity': '2151 Mystic Valley Parkway, Medford'},
#  {'geometry': {'location': {'lat': 42.24056239999999, 'lng': -70.9918793},
#    'viewport': {'northeast': {'lat': 42.24193358029151,
#      'lng': -70.9905221697085},
#     'southwest': {'lat': 42.23923561970851, 'lng': -70.9932201302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '0e0fb66e14114c44787f4814319abb4aa0f43e40',
#   'name': 'Kam Man Foods',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104824084233144813664/photos">Wendy C</a>'],
#     'photo_reference': 'CmRaAAAAiWyl1mSPH1VMRt40lzD92UxH8AiLS4SE8EdsMa3PAogu0XQuWzr3L64yhaa9S-98mkMuXG4RAtukXoambpr-LMtMq9_u7ruSUeEA6fK2Vht3sWQxRvH6H01ZRsAOisllEhB0n4jsRKau6-Mh_DJdUM8lGhQ1mPvZWmAOSMg5XvVMBd639w7EJw',
#     'width': 4032}],
#   'place_id': 'ChIJo_NsSTdj44kR06r7Y3EDjrk',
#   'plus_code': {'compound_code': '62R5+66 Quincy, Massachusetts, United States',
#    'global_code': '87JF62R5+66'},
#   'rating': 4.2,
#   'reference': 'ChIJo_NsSTdj44kR06r7Y3EDjrk',
#   'scope': 'GOOGLE',
#   'types': ['supermarket',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 496,
#   'vicinity': '219 Quincy Avenue, Quincy'},
#  {'geometry': {'location': {'lat': 42.2330347, 'lng': -71.1779592},
#    'viewport': {'northeast': {'lat': 42.23412113029151,
#      'lng': -71.1766394197085},
#     'southwest': {'lat': 42.23142316970851, 'lng': -71.1793373802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': 'ddc17ca536e20aaf24d01f3bf4eeb07635ab7ef6',
#   'name': 'Whole Foods Market',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2240,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114987648420604350923/photos">Han Chuang</a>'],
#     'photo_reference': 'CmRaAAAAjwjI4V5VmStM7xncPzmoooqaaJIQqTCpwYl2gTqdb9Q1J9aFK4qrlifU_zv7-_2AZ6cwPxwEFy5bcF0VUUhFPzagXSD2R00gAXxBxVu6CUlmgnvAEa44tUObRnXK7HTyEhADwtywCe5mCaqmSuMU_W5iGhRVENh7BP0VbGsviED-FPK3b_K4Lw',
#     'width': 4000}],
#   'place_id': 'ChIJ2Q0RoO9_44kR2u3IE20Q0iQ',
#   'plus_code': {'compound_code': '6RMC+6R Dedham, Massachusetts, United States',
#    'global_code': '87JC6RMC+6R'},
#   'price_level': 3,
#   'rating': 4.2,
#   'reference': 'ChIJ2Q0RoO9_44kR2u3IE20Q0iQ',
#   'scope': 'GOOGLE',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 337,
#   'vicinity': '300 Legacy Place, Dedham'},
#  {'geometry': {'location': {'lat': 42.116233, 'lng': -71.465242},
#    'viewport': {'northeast': {'lat': 42.1174601802915,
#      'lng': -71.46352901970849},
#     'southwest': {'lat': 42.1147622197085, 'lng': -71.4662269802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '58057281157b86a3ecaf0a74d4c111a38c155981',
#   'name': 'Walmart',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114274732690863282153/photos">Eddie Villalobos</a>'],
#     'photo_reference': 'CmRaAAAAWTRLNZIBOZwYuRQOcCHX163DI8ugAwxAJ2-gPHHV-U45kUkn-peRMaeUXhc1iqBF3BTenB5n32z6hDM4Mqs0N4Xh-KdLqH3nXhbEMCfYZV-kqABoqxE8_zrLKXvkJsVEEhCnOfnK4DJvuJxaYjjz8gXCGhRr2hwsMfbEx0xo5sxv92CiURUOlA',
#     'width': 5312}],
#   'place_id': 'ChIJKyPq4AJu5IkRCF9lAqZIIqQ',
#   'plus_code': {'compound_code': '4G8M+FW Bellingham, Bellingham Town, MA, United States',
#    'global_code': '87JC4G8M+FW'},
#   'price_level': 1,
#   'rating': 4,
#   'reference': 'ChIJKyPq4AJu5IkRCF9lAqZIIqQ',
#   'scope': 'GOOGLE',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 417,
#   'vicinity': '250 Hartford Avenue, Bellingham'},
#  {'geometry': {'location': {'lat': 42.08665750000001, 'lng': -71.2695868},
#    'viewport': {'northeast': {'lat': 42.0880549802915,
#      'lng': -71.26825836970849},
#     'southwest': {'lat': 42.0853570197085, 'lng': -71.2709563302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': 'e2e10540400d8b55dca1f5737365ababe0250ef7',
#   'name': "Trader Joe's",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111797252045865114246/photos">Sam Sanson</a>'],
#     'photo_reference': 'CmRaAAAARscNq6NwxIRdY6c6npBDOG-KBJgqwXB_3OtuURTqgS2fdfNIdc3qeb_sQiSci1UDhOzfy2fjXkDenaVpb6JsuNoKRf7w-zUP5OjRG_h2Yo0i0LQ_urciphO_28TcGzAmEhAee3b7fBwxg5NQk_buZHOiGhR7CTJKk4ECNvD8oSKs0QinaRZBBQ',
#     'width': 4032}],
#   'place_id': 'ChIJz0djm7Z85IkRgVWZjiLbmsE',
#   'plus_code': {'compound_code': '3PPJ+M5 Foxborough, Massachusetts, United States',
#    'global_code': '87JC3PPJ+M5'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJz0djm7Z85IkRgVWZjiLbmsE',
#   'scope': 'GOOGLE',
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'liquor_store',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 584,
#   'vicinity': '350 Patriot Place, Foxborough'},
#  {'geometry': {'location': {'lat': 42.3758659, 'lng': -71.1032516},
#    'viewport': {'northeast': {'lat': 42.3772374802915,
#      'lng': -71.1016960197085},
#     'southwest': {'lat': 42.3745395197085, 'lng': -71.1043939802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '3e340280681b205f004cdd89dc7eac84fca46f2b',
#   'name': 'Whole Foods Market',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115832882436993992452/photos">Sheraz Choudhary</a>'],
#     'photo_reference': 'CmRaAAAAzPnOw4lBfaxSqaSi_yU8OAa5bhj_Sud1nsmSnMMHxyVINPl0MRgeE3gOJYLVHVbaHHeYwNIcJ5TM1eqDy0EC1i1MnzKmWSGD1LAhqRQWfo4sWe83AVmcLxoiUd2B0mKJEhBs4xstnrZVDYXOOHw1BcjZGhTHG23theGlNDjaGM7nE4EOUOPfPQ',
#     'width': 4032}],
#   'place_id': 'ChIJj7oq2Et344kRnb1BcIMee-Y',
#   'plus_code': {'compound_code': '9VGW+8M Somerville, Massachusetts, United States',
#    'global_code': '87JC9VGW+8M'},
#   'price_level': 3,
#   'rating': 4.2,
#   'reference': 'ChIJj7oq2Et344kRnb1BcIMee-Y',
#   'scope': 'GOOGLE',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 389,
#   'vicinity': '45 Beacon Street, Somerville'},
#  {'geometry': {'location': {'lat': 42.473428, 'lng': -71.2106665},
#    'viewport': {'northeast': {'lat': 42.47464558029149,
#      'lng': -71.2094519697085},
#     'southwest': {'lat': 42.47194761970849, 'lng': -71.2121499302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '3d5696850fbfbc4918061bc999c586e11513d605',
#   'name': "Trader Joe's",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1979,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101680911302232040523/photos">Daniel Sullivan</a>'],
#     'photo_reference': 'CmRaAAAAieI0-V7NnQ8FwX-yf1kk9l4m5PjCGKVbFl-2scFCvCX2ey_LnK_vxO7hyRvFVTBnMy8dhkE_Hx5KfhLf9YN5gGp9N6vH8b1otrxL-zA4CEtfeTI9qCeCNW7EpH4zDQVjEhCMytPFoNWmts1nwuFn-_QUGhR85UKNJiB3Lc-snpYXchsWYaYVwg',
#     'width': 3518}],
#   'place_id': 'ChIJ8wYV9hWe44kRrrBHV8zXOSk',
#   'plus_code': {'compound_code': 'FQFQ+9P Burlington, Massachusetts, United States',
#    'global_code': '87JCFQFQ+9P'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJ8wYV9hWe44kRrrBHV8zXOSk',
#   'scope': 'GOOGLE',
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 453,
#   'vicinity': '51 Middlesex Turnpike, Burlington'},
#  {'geometry': {'location': {'lat': 42.3755356, 'lng': -71.0661184},
#    'viewport': {'northeast': {'lat': 42.37691640000001, 'lng': -71.0633478},
#     'southwest': {'lat': 42.3738616, 'lng': -71.06871659999999}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '42593c3a70357131e707168403befcdb6cd948be',
#   'name': 'Whole Foods Market',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3038,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103883897278594082398/photos">Hai Cao</a>'],
#     'photo_reference': 'CmRaAAAAqnw55HeldTwiURtcfUqutfKmBXMPBFEnnxhcdBuF_F9PnJZbnIv1UHG2abAiRF9Pnr01vQWG2ccqZyR8CWrgRv-6NstSLmrNmKtVNBFmfpV4Dpi8gyPfy6njWjxf88DMEhDjpWe2WTnPZcImk77F8ej9GhQoEXGavLzhXqS8A9GAr-3bdi-kwA',
#     'width': 4050}],
#   'place_id': 'ChIJZziLZ-xw44kRp8J-N9vM53Y',
#   'plus_code': {'compound_code': '9WGM+6H Boston, Massachusetts, United States',
#    'global_code': '87JC9WGM+6H'},
#   'price_level': 3,
#   'rating': 4.3,
#   'reference': 'ChIJZziLZ-xw44kRp8J-N9vM53Y',
#   'scope': 'GOOGLE',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 496,
#   'vicinity': '51 Austin Street, Charlestown'},
#  {'geometry': {'location': {'lat': 42.346179, 'lng': -71.10826569999999},
#    'viewport': {'northeast': {'lat': 42.3476203802915,
#      'lng': -71.10700441970847},
#     'southwest': {'lat': 42.3449224197085, 'lng': -71.1097023802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '3105aadea009fd4a269d886f491492888936b061',
#   'name': 'Whole Foods Market',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106656757212598532235/photos">Andie Smidler</a>'],
#     'photo_reference': 'CmRaAAAA8EzJZd9Ia1oA7hLJaRczw31A7rFwcbNRRqMp8Ow_-SBbqX61Es4d5SwvGi-3EuFnH0mQVyN2I_joYI3ay9yN61PrA-iRYBp6oFgxRT24XIkWaHP5aA0TJJTrcJ9hlfV4EhBiFhNGHE1B2BvmoQMYucLFGhRlXeNTsp1Xvx9L36GcJNodvcLKuA',
#     'width': 4032}],
#   'place_id': 'ChIJz7UWGvJ544kROfCqT14Q5Q0',
#   'plus_code': {'compound_code': '8VWR+FM Brookline, Massachusetts, United States',
#    'global_code': '87JC8VWR+FM'},
#   'price_level': 3,
#   'rating': 4.1,
#   'reference': 'ChIJz7UWGvJ544kROfCqT14Q5Q0',
#   'scope': 'GOOGLE',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 283,
#   'vicinity': '1028 Beacon Street, Brookline'},
#  {'geometry': {'location': {'lat': 42.49100089999999, 'lng': -71.2728918},
#    'viewport': {'northeast': {'lat': 42.49218143029149,
#      'lng': -71.27162796970849},
#     'southwest': {'lat': 42.48948346970849, 'lng': -71.27432593029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': 'f4fcdde06fca7ddb99f84348de71a3d5f36cc774',
#   'name': 'Whole Foods Market',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108484012362067852034/photos">Kyle O&#39;Connor</a>'],
#     'photo_reference': 'CmRaAAAAOa7TLhERA8vvmyCDh2e_sCL6Ts4xcPst5B-T-LNlCdD5dYCQF4AjAJi9C6_8oSIjTtrlt7253uSaZKKJ_QSXC7bL50P9F8vrnxxvk0p_oi4luLL__XDJ3T10H3mdzKzREhC7U1U1T_1staltuNJti5MsGhSAJNaWghXh6jvAZ0DWv6vMYIkI9w',
#     'width': 4032}],
#   'place_id': 'ChIJb7JPlcWe44kR_PC2feH9QU0',
#   'plus_code': {'compound_code': 'FPRG+CR Bedford, Massachusetts, United States',
#    'global_code': '87JCFPRG+CR'},
#   'price_level': 3,
#   'rating': 4.1,
#   'reference': 'ChIJb7JPlcWe44kR_PC2feH9QU0',
#   'scope': 'GOOGLE',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 150,
#   'vicinity': '170 Great Road, Bedford'},
#  {'geometry': {'location': {'lat': 42.4254178, 'lng': -71.1888223},
#    'viewport': {'northeast': {'lat': 42.4266850802915,
#      'lng': -71.18751166970848},
#     'southwest': {'lat': 42.4239871197085, 'lng': -71.1902096302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '76acb927eee17e7ac0bbb23eac6104d6c5eee5fd',
#   'name': "Trader Joe's",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 720,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108793317285962957461/photos">Trader Joe&#39;s</a>'],
#     'photo_reference': 'CmRaAAAASuLdsPYIt3P34wYE1srZnSwm_iy2Rh8rEu2ousbuTgkdLNPufZWE18umVTKsG-t68cCHH5w-n_CSbwS7maBNLAVmHuZ-RQOaZQkEOXnWwx2jJB38vMWRov5WUR11FZElEhA55FAeG2Xsy9LLWtFimBMpGhQMc8fLjdNHf8GRbwVFnu216ODUvg',
#     'width': 720}],
#   'place_id': 'ChIJKUcgkyZ244kResOpp0UKRf8',
#   'plus_code': {'compound_code': 'CRG6+5F Arlington, Massachusetts, United States',
#    'global_code': '87JCCRG6+5F'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJKUcgkyZ244kResOpp0UKRf8',
#   'scope': 'GOOGLE',
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 409,
#   'vicinity': '1427 Massachusetts Avenue, Arlington'},
#  {'geometry': {'location': {'lat': 42.475283, 'lng': -71.448824},
#    'viewport': {'northeast': {'lat': 42.4764677802915,
#      'lng': -71.4475403197085},
#     'southwest': {'lat': 42.4737698197085, 'lng': -71.4502382802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '15b81b8baa498111c343869c38a01cfe37ed3e85',
#   'name': 'Roche Bros. Acton',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100822964068787153334/photos">Joshua Chaitin-Pollak</a>'],
#     'photo_reference': 'CmRaAAAAuc7QOlQf1wJ9Uiyn5F3iGN6jV_UMD8vjhfA-NPXtxIAVp4P9Nv7xLrTYrU5o-Y85gq-Bzb3C7i8LDX1l4RMtl3DZVKwVaHX92o4P9NzUcRI_afEJxruwSytDD4Eb0hRxEhCiiowKKovclZuNaLF0cnMQGhRD8IB_aMtqMrdDPSxQkTXd6Z6Axg',
#     'width': 1920}],
#   'place_id': 'ChIJLRzwmBWR44kRiEont58xJGU',
#   'plus_code': {'compound_code': 'FHG2+4F Acton, Massachusetts, United States',
#    'global_code': '87JCFHG2+4F'},
#   'rating': 4.1,
#   'reference': 'ChIJLRzwmBWR44kRiEont58xJGU',
#   'scope': 'GOOGLE',
#   'types': ['supermarket',
#    'florist',
#    'bakery',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 113,
#   'vicinity': '387 Massachusetts Avenue, Acton'},
#  {'geometry': {'location': {'lat': 42.3463576, 'lng': -71.0650258},
#    'viewport': {'northeast': {'lat': 42.34773543029149,
#      'lng': -71.0637804197085},
#     'southwest': {'lat': 42.34503746970849, 'lng': -71.0664783802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': 'c7a2d2696fba3ebd0ce44a3c838829f0545980a3',
#   'name': 'C-Mart Supermarket',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105209365503839609989/photos">Iori Ng</a>'],
#     'photo_reference': 'CmRaAAAAmIg7NDhGI8i6Y-9VVcIcMsVSK9LNxb3oR_p6Wo2puUvnsLnGNYM8jakeidzF1XpKObklPpCVWm1XJ-wuyNkUvDG81hzM0GyaqEo9E9ISo8XvOHtHsO4t-KXYgiwmHYsUEhB8GEeSc1LCroPY6B28jOG1GhS9kPRSRgqRbO1FnBXsKZn5Odf1KQ',
#     'width': 3024}],
#   'place_id': 'ChIJzwcTqXF644kRnLFDPZEwxTQ',
#   'plus_code': {'compound_code': '8WWM+GX Boston, Massachusetts, United States',
#    'global_code': '87JC8WWM+GX'},
#   'rating': 3.9,
#   'reference': 'ChIJzwcTqXF644kRnLFDPZEwxTQ',
#   'scope': 'GOOGLE',
#   'types': ['supermarket',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 412,
#   'vicinity': '50 Herald Street, Boston'},
#  {'geometry': {'location': {'lat': 42.24992, 'lng': -70.920863},
#    'viewport': {'northeast': {'lat': 42.25126898029149,
#      'lng': -70.91965121970848},
#     'southwest': {'lat': 42.24857101970849, 'lng': -70.9223491802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': 'dfae310a630b94027c32285ae8613a178b3904f1',
#   'name': 'The Fresh Market',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115328718470326767851/photos">Tim Pranaitis</a>'],
#     'photo_reference': 'CmRaAAAAX9DQWio-QWuYiP-c3knBE5GxLH2-3JXKI-iuQFx5OXRaseD2GOAJnrRhXPeBSLjcjLB1F1vcx48EzmlyHIjezdWhEMKiDCT_aXiEuEU72mcf6PX-L4b9EPJLhusM6sJ9EhAeEut2al9rc3koeZrdcl-0GhR6zTVYI9fVm0OvDAG5FL8D9WFf2g',
#     'width': 1920}],
#   'place_id': 'ChIJp8YkAvdj44kRWjTgfbz2ewI',
#   'plus_code': {'compound_code': '63XH+XM Hingham, MA, United States',
#    'global_code': '87JF63XH+XM'},
#   'price_level': 3,
#   'rating': 4.4,
#   'reference': 'ChIJp8YkAvdj44kRWjTgfbz2ewI',
#   'scope': 'GOOGLE',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 171,
#   'vicinity': '11 Essington Drive, Hingham'},
#  {'geometry': {'location': {'lat': 42.3013234, 'lng': -71.29282669999999},
#    'viewport': {'northeast': {'lat': 42.30253838029151,
#      'lng': -71.2913508197085},
#     'southwest': {'lat': 42.29984041970851, 'lng': -71.2940487802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '523a6e7c8c23e8983da95fcfc381155d8d08ecfa',
#   'name': 'Roche Bros. Wellesley',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1280,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115181614025230252016/photos">Roche Bros. Wellesley</a>'],
#     'photo_reference': 'CmRaAAAAdduwEZFpPkM0T2HG4EgPYZg4zcOxQ2E_usrjdYe46iAaYhbCT5N2cFL8brw_vtzy_Aho04z13j1--sgQ5yA-_94LTvsr7VzMeO0hpETDIr5GIRr5iDZoWUiDp9YFy8kLEhBdJsCjS2BXNm-qrHi85Q1DGhQw51IdI86Kvk_lhu1Z_NMqN2uZeg',
#     'width': 1920}],
#   'place_id': 'ChIJSx0NLLSG44kR_MAy4eonS9s',
#   'plus_code': {'compound_code': '8P24+GV Wellesley, Massachusetts, United States',
#    'global_code': '87JC8P24+GV'},
#   'rating': 4.2,
#   'reference': 'ChIJSx0NLLSG44kR_MAy4eonS9s',
#   'scope': 'GOOGLE',
#   'types': ['supermarket',
#    'florist',
#    'meal_delivery',
#    'bakery',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 183,
#   'vicinity': '184 Linden Street, Wellesley'},
#  {'geometry': {'location': {'lat': 42.0963, 'lng': -70.96849999999999},
#    'viewport': {'northeast': {'lat': 42.09735543029149,
#      'lng': -70.96733876970849},
#     'southwest': {'lat': 42.09465746970849, 'lng': -70.9700367302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': 'eb576994b4067f96c8874a727d2f9bfbd3a4d689',
#   'name': 'Walmart',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113015894990283567899/photos">Rogers Marques</a>'],
#     'photo_reference': 'CmRaAAAAYZhKtjgL9YKxVA__e9t26GWiU2Yd7dDOG0psrf7rQEh9GC-htkDN8vBJXTioumhhq_J_e9PVCoySNRgCZda5chbeaeOm0ib4gspgneLKnfKUDaSh3nRe-_iM8o4SnqfdEhAyrjFazBDJkgAPQQsmBv5vGhSIfRpVhTznWQ2ZejH3fOSi2fnk_g',
#     'width': 5312}],
#   'place_id': 'ChIJTxHf2G2b5IkR2BgSaknj3RU',
#   'plus_code': {'compound_code': '32WJ+GJ Abington, Massachusetts, United States',
#    'global_code': '87JF32WJ+GJ'},
#   'price_level': 1,
#   'rating': 3.9,
#   'reference': 'ChIJTxHf2G2b5IkR2BgSaknj3RU',
#   'scope': 'GOOGLE',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 977,
#   'vicinity': '777 Brockton Avenue, Abington'},
#  {'geometry': {'location': {'lat': 42.5046436, 'lng': -70.9199823},
#    'viewport': {'northeast': {'lat': 42.5058790302915,
#      'lng': -70.91883746970849},
#     'southwest': {'lat': 42.5031810697085, 'lng': -70.9215354302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': '7fcf0ad88b25dc03c377ed2f86ad4a12794f8845',
#   'name': 'Market Basket',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111704714362262488449/photos">Alfredo Pina</a>'],
#     'photo_reference': 'CmRaAAAA7m4vTyncOeF0U7kAnC3S6NNghj2eIYS-56gPPt7J1R49WVa-th_FdHQeKLyB1j28TXkXvWEvT3wDhiRvqktzMGWso4mhZ68kk18QhRyYHokhhgPTlm2zr2ZBQZhuRkQXEhBlZ5lcgDw3zZ2wsptIyJEgGhQ4I79QrN2bphfZZO_ssnQ9uJr1QA',
#     'width': 4032}],
#   'place_id': 'ChIJVQcRLW8T44kR7gCQpO6bxpo',
#   'plus_code': {'compound_code': 'G33J+V2 Salem, Massachusetts, United States',
#    'global_code': '87JFG33J+V2'},
#   'rating': 4.2,
#   'reference': 'ChIJVQcRLW8T44kR7gCQpO6bxpo',
#   'scope': 'GOOGLE',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 1067,
#   'vicinity': '227 Highland Avenue, Salem'},
#  {'geometry': {'location': {'lat': 42.281245, 'lng': -71.37716499999999},
#    'viewport': {'northeast': {'lat': 42.2827270302915,
#      'lng': -71.37580136970848},
#     'southwest': {'lat': 42.2800290697085, 'lng': -71.3784993302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#   'id': 'fca19b54713e09d1cd18b15349f02c87e251b69b',
#   'name': 'Roche Bros. Natick',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3072,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103456480419633062162/photos">Roche Bros. Natick</a>'],
#     'photo_reference': 'CmRZAAAAC8l3FPnzBaJbfSUskI33rLwmi_-5KwbBRoLymDPVm0vrCTYjIwAF_XaihRGSR8rm7FI9x1cDj1mgKNomUBm_0IcqmcDqUFvu0Iph213u3XOODe70lcRMfSEls64YVFwDEhCVOhuqFw4QPj1592iHETljGhQjUAyEVn5ldagoQDqrJtQ4DXyp7w',
#     'width': 2304}],
#   'place_id': 'ChIJg_Z_49mH44kRHNMcuXGSp1o',
#   'plus_code': {'compound_code': '7JJF+F4 Natick, Massachusetts, United States',
#    'global_code': '87JC7JJF+F4'},
#   'rating': 4.2,
#   'reference': 'ChIJg_Z_49mH44kRHNMcuXGSp1o',
#   'scope': 'GOOGLE',
#   'types': ['supermarket',
#    'florist',
#    'bakery',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 545,
#   'vicinity': '150 West Central Street, Natick'}]

# %%
for i in data:
    print(i['name'])
# Out:
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Whole Foods Market
# Walmart
# Trader Joe's
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart
# Walmart Supercenter
# Market Basket
# Walmart
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Walmart
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Walmart
# Market Basket
# Roche Bros. Natick

# %%
len(data)
# Out:
# 60

# %%
allston = '42.3529,-71.1321'
backbay = '42.3507752636,-71.0748797005'
beacon_hill ='42.3587999,-71.0707389'
brighton ='42.317980,-71.158510'
charlestown ='42.392600,-71.093980'
chinatown = '42.347960,-71.056410'
Dochester = '42.299780,-71.078840'
downtown = '42.355300,-71.055280'
east_boston ='42.375401,-71.039482'
fenway_kenmore = '42.345480,-71.101700'
Hyde_Park = '42.255810,-71.124130'
Jamaica_Plain = '42.310880,-71.125060'
Mattapan = '42.252160,-71.124950'
Mission_Hill = '42.334000,-71.097910'
North_end = '42.365530,-71.060880'
Roslindale = '42.317980,-71.158510'
Roxbury ='42.317980,-71.158510'
south_end = '42.332670,-71.097910'
south_boston ='42.337541,-71.042942'
west_end = '42.364397,-71.065958'
west_roxbury = '42.284392,-71.161520'
bos_loc = "42.3600825,-71.0588801"

locations = [allston,backbay,beacon_hill,brighton,charlestown,chinatown,Dochester,downtown,east_boston,fenway_kenmore,
            Hyde_Park,Jamaica_Plain,Mattapan,Mission_Hill,North_end,Roslindale,Roxbury,south_end,south_boston,west_end
            ,west_roxbury,bos_loc]

key = dml.auth['services']['googleprotocal']['key']

prefix = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
_type = 'grocery_or_supermarket'
radius = '50000'
next_pg_token = []
data = []

for location in locations:
    print(location)
    url = prefix +'location='+location+"&radius="+radius+"&type="+_type+"&key="+key
    print(url)
    response = urllib.request.urlopen(url).read().decode("utf-8")
    r = json.loads(response)
    count = 0
    
    while ('next_page_token' in r):
        count += 1
        print(count)
        nextpg=r['next_page_token']

        data = data + (r['results'])

        url = prefix+"pagetoken="+nextpg+"&key="+key

        response = urllib.request.urlopen(url).read().decode()
        r = json.loads(response)
        while (r['status'] == 'INVALID_REQUEST'):
            time.sleep(.300)
            response = urllib.request.urlopen(url).read().decode()
            r = json.loads(response)
    data = data + r['results']
# Out:
# 42.3529,-71.1321
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.3529,-71.1321&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.3507752636,-71.0748797005
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.3507752636,-71.0748797005&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.3587999,-71.0707389
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.3587999,-71.0707389&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.317980,-71.158510
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.317980,-71.158510&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.392600,-71.093980
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.392600,-71.093980&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.347960,-71.056410
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.347960,-71.056410&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.299780,-71.078840
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.299780,-71.078840&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.355300,-71.055280
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.355300,-71.055280&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.375401,-71.039482
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.375401,-71.039482&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.345480,-71.101700
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.345480,-71.101700&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.255810,-71.124130
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.255810,-71.124130&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.310880,-71.125060
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.310880,-71.125060&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.252160,-71.124950
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.252160,-71.124950&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.334000,-71.097910
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.334000,-71.097910&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.365530,-71.060880
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.365530,-71.060880&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.317980,-71.158510
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.317980,-71.158510&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.317980,-71.158510
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.317980,-71.158510&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.332670,-71.097910
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.332670,-71.097910&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.337541,-71.042942
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.337541,-71.042942&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.364397,-71.065958
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.364397,-71.065958&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.284392,-71.161520
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.284392,-71.161520&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2
# 42.3600825,-71.0588801
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.3600825,-71.0588801&radius=50000&type=supermarket&key=AIzaSyBLry03J-rZZJ2sz1qLRm5Wwvqq4APEkKA
# 1
# 2

# %%
for i in data:
    print(i['name'])
# Out:
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Whole Foods Market
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Trader Joe's
# Walmart Supercenter
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Market Basket
# Walmart
# Trader Joe's
# Big Y World Class Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Walmart
# Market Basket
# Trader Joe's
# Save-A-Lot
# Market Basket
# Bazaar On Beacon Street
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Walmart
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Trader Joe's
# Roche Bros. Natick
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Whole Foods Market
# Walmart
# Trader Joe's
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Trader Joe's
# Walmart
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Walmart
# Kam Man Foods
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Walmart
# Market Basket
# Roche Bros. Natick
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Whole Foods Market
# Walmart
# Trader Joe's
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Walmart Supercenter
# Walmart
# Trader Joe's
# Market Basket
# Walmart
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Walmart
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Walmart
# Market Basket
# Roche Bros. Natick
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Market Basket
# Walmart
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Whole Foods Market
# Trader Joe's
# Walmart Supercenter
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Market Basket
# Trader Joe's
# Walmart
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Market Basket
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Walmart
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart Supercenter
# Roche Bros. Acton
# Trader Joe's
# Whole Foods Market
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Walmart
# Market Basket
# Walmart
# Walmart Supercenter
# Market Basket
# Whole Foods Market
# Trader Joe's
# Walmart
# Trader Joe's
# ALDI
# Whole Foods Market
# Trader Joe's
# Walmart
# Market Basket
# Whole Foods Market
# Walmart Supercenter
# Whole Foods Market
# Walmart
# Market Basket
# Trader Joe's
# Trader Joe's
# Walmart
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Whole Foods Market
# Market Basket
# Trader Joe's
# Save-A-Lot
# Market Basket
# Bazaar On Beacon Street
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Walmart
# Whole Foods Market
# Trader Joe's
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Trader Joe's
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart
# Market Basket
# Walmart Supercenter
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Walmart
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Whole Foods Market
# Market Basket
# Kam Man Foods
# Whole Foods Market
# Walmart
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Walmart
# Market Basket
# Roche Bros. Natick
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Market Basket
# Walmart
# Walmart
# Market Basket
# Trader Joe's
# Walmart
# Trader Joe's
# Walmart Supercenter
# ALDI
# Whole Foods Market
# Trader Joe's
# Walmart
# Whole Foods Market
# Whole Foods Market
# Market Basket
# Whole Foods Market
# Trader Joe's
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Walmart
# Whole Foods Market
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Walmart
# Roche Bros. Wellesley
# Roche Bros. Natick
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Whole Foods Market
# Walmart
# Trader Joe's
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart
# Market Basket
# Walmart Supercenter
# Trader Joe's
# Walmart
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Walmart
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Walmart
# Market Basket
# Roche Bros. Natick
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Walmart
# Walmart
# Market Basket
# Walmart Supercenter
# Market Basket
# Whole Foods Market
# Trader Joe's
# Walmart
# Trader Joe's
# ALDI
# Trader Joe's
# Whole Foods Market
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Walmart
# Market Basket
# Trader Joe's
# Walmart Supercenter
# Whole Foods Market
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Market Basket
# Save-A-Lot
# Trader Joe's
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Market Basket
# Walmart
# Roche Bros. Natick
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Walmart Supercenter
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Market Basket
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Whole Foods Market
# Walmart
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Walmart
# Roche Bros. Natick
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Market Basket
# Walmart
# Walmart
# Market Basket
# Trader Joe's
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Trader Joe's
# Walmart Supercenter
# Walmart
# Walmart Supercenter
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart
# Market Basket
# Whole Foods Market
# Walmart Supercenter
# Walmart
# Market Basket
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Walmart Supercenter
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# Whole Foods Market
# C-Mart Supermarket
# The Fresh Market
# Walmart
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Market Basket
# Walmart
# Walmart
# Walmart
# Market Basket
# Walmart Supercenter
# Trader Joe's
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Trader Joe's
# Whole Foods Market
# Walmart Supercenter
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Market Basket
# Trader Joe's
# Walmart
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Market Basket
# Save-A-Lot
# Bazaar On Beacon Street
# Whole Foods Market
# Kam Man Foods
# Market Basket
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Walmart Supercenter
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Whole Foods Market
# Walmart
# Roche Bros. Wellesley
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Market Basket
# Walmart
# Walmart
# Market Basket
# Trader Joe's
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Trader Joe's
# Walmart Supercenter
# Walmart Supercenter
# Walmart
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart
# Market Basket
# Walmart Supercenter
# Walmart
# Whole Foods Market
# Big Y World Class Market
# Market Basket
# Whole Foods Market
# Trader Joe's
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Whole Foods Market
# Market Basket
# Kam Man Foods
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Walmart Supercenter
# Whole Foods Market
# Trader Joe's
# ALDI
# Whole Foods Market
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Market Basket
# Walmart
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Walmart Supercenter
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Market Basket
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Walmart
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Walmart
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Walmart
# Walmart Supercenter
# Roche Bros. Natick
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Whole Foods Market
# Trader Joe's
# Walmart
# Trader Joe's
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart
# Walmart Supercenter
# Market Basket
# Walmart
# Trader Joe's
# Whole Foods Market
# Big Y World Class Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Walmart
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Walmart
# Market Basket
# Roche Bros. Natick
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Market Basket
# Walmart
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Whole Foods Market
# Trader Joe's
# Walmart Supercenter
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Market Basket
# Trader Joe's
# Walmart
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Market Basket
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Walmart
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart Supercenter
# Roche Bros. Acton
# Trader Joe's
# Whole Foods Market
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Market Basket
# Walmart
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Whole Foods Market
# Trader Joe's
# Walmart Supercenter
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Market Basket
# Trader Joe's
# Walmart
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Market Basket
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Walmart
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart Supercenter
# Roche Bros. Acton
# Trader Joe's
# Whole Foods Market
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Market Basket
# Walmart
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Walmart Supercenter
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Market Basket
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Walmart
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Walmart
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Walmart Supercenter
# Roche Bros. Wellesley
# Walmart
# Roche Bros. Natick
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Market Basket
# Walmart Supercenter
# Trader Joe's
# Walmart
# Walmart
# Trader Joe's
# Whole Foods Market
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart
# Market Basket
# Trader Joe's
# Walmart Supercenter
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Market Basket
# Walmart
# Walmart
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Walmart
# Roche Bros. Wellesley
# Market Basket
# Roche Bros. Natick
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Whole Foods Market
# Trader Joe's
# Walmart
# Trader Joe's
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Walmart Supercenter
# Market Basket
# Walmart
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Walmart
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Walmart
# Market Basket
# Roche Bros. Natick
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Market Basket
# Walmart
# Walmart
# Market Basket
# Trader Joe's
# Walmart
# Walmart
# Trader Joe's
# Walmart Supercenter
# Whole Foods Market
# ALDI
# Trader Joe's
# Whole Foods Market
# Walmart Supercenter
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Walmart
# Trader Joe's
# Walmart
# Market Basket
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Save-A-Lot
# Market Basket
# Bazaar On Beacon Street
# Walmart Supercenter
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Market Basket
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Walmart Supercenter
# Trader Joe's
# Trader Joe's
# Roche Bros. Acton
# Whole Foods Market
# C-Mart Supermarket
# The Fresh Market
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Walmart
# Walmart Supercenter
# Trader Joe's
# Walmart
# Market Basket
# Walmart
# Walmart
# Walmart Supercenter
# Market Basket
# Trader Joe's
# Whole Foods Market
# Walmart
# Trader Joe's
# ALDI
# Whole Foods Market
# Trader Joe's
# Market Basket
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Walmart
# Walmart Supercenter
# Market Basket
# Walmart
# Trader Joe's
# Big Y World Class Market
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Market Basket
# Trader Joe's
# Save-A-Lot
# Bazaar On Beacon Street
# Market Basket
# Whole Foods Market
# Kam Man Foods
# Whole Foods Market
# Walmart
# Trader Joe's
# Whole Foods Market
# Trader Joe's
# Whole Foods Market
# Whole Foods Market
# Whole Foods Market
# Trader Joe's
# Roche Bros. Acton
# C-Mart Supermarket
# The Fresh Market
# Roche Bros. Wellesley
# Walmart
# Market Basket
# Roche Bros. Natick

# %%
supermarket = []
ids = []
for x in data:
    temp = {}
    if x['id'] not in ids:
        ids.append(x['id'])
        temp['name'] = x['name']
        temp['types'] = x['types']
        if 'price_level' in x:
            temp['price_level'] = x['price_level']
        else:
            temp['price_level'] = 'N/A'
       
        temp['address'] = x['vicinity']
        temp['neighborhood'] = x['vicinity'].split(',')[1].strip()
        supermarket.append(temp)
    else:
        continue

# %%
for i in data:
    print(i['price_level'])
# Out:
# 3
# 3
# 3
# 3
# 3
# 2
# 3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-3b9dc751775c> in <module>()
#       1 for i in data:
# ----> 2     print(i['price_level'])
#
# KeyError: 'price_level'

# %%
'price_level' in data[1]
# Out:
# True

# %%
supermarket
# Out:
# [{'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '181 Cambridge Street, Boston',
#   'neighborhood': 'Boston'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '15 Westland Avenue, Boston',
#   'neighborhood': 'Boston'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '340 River Street, Cambridge',
#   'neighborhood': 'Cambridge'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '15 Washington Street, Brighton',
#   'neighborhood': 'Brighton'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '115 Prospect Street, Cambridge',
#   'neighborhood': 'Cambridge'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '211 Alewife Brook Parkway, Cambridge',
#   'neighborhood': 'Cambridge'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '200 Alewife Brook Parkway, Cambridge',
#   'neighborhood': 'Cambridge'},
#  {'name': 'Market Basket',
#   'types': ['supermarket',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '170 Everett Avenue, Chelsea',
#   'neighborhood': 'Chelsea'},
#  {'name': 'Walmart',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '780 Lynnway, Lynn',
#   'neighborhood': 'Lynn'},
#  {'name': 'Walmart Supercenter',
#   'types': ['department_store',
#    'supermarket',
#    'grocery_or_supermarket',
#    'electronics_store',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '550 Providence Highway, Walpole',
#   'neighborhood': 'Walpole'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '958 Highland Avenue, Needham',
#   'neighborhood': 'Needham'},
#  {'name': 'Walmart',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '66 Parkhurst Road, Chelmsford',
#   'neighborhood': 'Chelmsford'},
#  {'name': 'Market Basket',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '49 Pond Street, Ashland',
#   'neighborhood': 'Ashland'},
#  {'name': 'Walmart',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '72 Main Street, North Reading',
#   'neighborhood': 'North Reading'},
#  {'name': 'Walmart',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '55 Brooksby Village Drive, Danvers',
#   'neighborhood': 'Danvers'},
#  {'name': 'Walmart Supercenter',
#   'types': ['department_store',
#    'supermarket',
#    'grocery_or_supermarket',
#    'electronics_store',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '333 Main Street, Tewksbury',
#   'neighborhood': 'Tewksbury'},
#  {'name': 'Market Basket',
#   'types': ['supermarket',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '400 Somerville Avenue, Somerville',
#   'neighborhood': 'Somerville'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '748 Memorial Drive, Cambridge',
#   'neighborhood': 'Cambridge'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '40 Railroad Street, Andover',
#   'neighborhood': 'Andover'},
#  {'name': 'Walmart',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '301 Falls Boulevard, Quincy',
#   'neighborhood': 'Quincy'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'liquor_store',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '1317 Beacon Street, Brookline',
#   'neighborhood': 'Brookline'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '575 Worcester Road, Framingham',
#   'neighborhood': 'Framingham'},
#  {'name': 'ALDI',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '630 Fellsway, Medford',
#   'neighborhood': 'Medford'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '899 Boylston Street, Boston',
#   'neighborhood': 'Boston'},
#  {'name': 'Walmart Supercenter',
#   'types': ['department_store',
#    'supermarket',
#    'grocery_or_supermarket',
#    'electronics_store',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '280 Washington Street, Hudson',
#   'neighborhood': 'Hudson'},
#  {'name': 'Market Basket',
#   'types': ['grocery_or_supermarket',
#    'bakery',
#    'supermarket',
#    'store',
#    'restaurant',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '1900 Main Street, Tewksbury',
#   'neighborhood': 'Tewksbury'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '331 Paradise Road, Swampscott',
#   'neighborhood': 'Swampscott'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '647 Washington Street, Newton',
#   'neighborhood': 'Newton'},
#  {'name': 'Walmart',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '121 Worcester Road, Framingham',
#   'neighborhood': 'Framingham'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '1775 Washington Street, Hanover',
#   'neighborhood': 'Hanover'},
#  {'name': 'Market Basket',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '230 South Main Street, Middleton',
#   'neighborhood': 'Middleton'},
#  {'name': 'Walmart',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '70 Pleasant Valley Street, Methuen',
#   'neighborhood': 'Methuen'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'liquor_store',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '300 Andover Street, Peabody',
#   'neighborhood': 'Peabody'},
#  {'name': 'Big Y World Class Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '1111 Providence Highway, Walpole',
#   'neighborhood': 'Walpole'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '1121 Washington Street, West Newton',
#   'neighborhood': 'West Newton'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '94 Derby Street, Hingham',
#   'neighborhood': 'Hingham'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '427 Walnut Street, Lynnfield',
#   'neighborhood': 'Lynnfield'},
#  {'name': 'Walmart',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '250 Hartford Avenue, Bellingham',
#   'neighborhood': 'Bellingham'},
#  {'name': 'Market Basket',
#   'types': ['supermarket',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '139 Endicott Street, Danvers',
#   'neighborhood': 'Danvers'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'liquor_store',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '659 Worcester Road, Framingham',
#   'neighborhood': 'Framingham'},
#  {'name': 'Save-A-Lot',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '330 Martin Luther King Jr Boulevard, Roxbury',
#   'neighborhood': 'Roxbury'},
#  {'name': 'Market Basket',
#   'types': ['supermarket',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '199 Boston Road, North Billerica',
#   'neighborhood': 'North Billerica'},
#  {'name': 'Bazaar On Beacon Street',
#   'types': ['supermarket',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '1432 Beacon Street, Brookline',
#   'neighborhood': 'Brookline'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '2151 Mystic Valley Parkway, Medford',
#   'neighborhood': 'Medford'},
#  {'name': 'Kam Man Foods',
#   'types': ['supermarket',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '219 Quincy Avenue, Quincy',
#   'neighborhood': 'Quincy'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '300 Legacy Place, Dedham',
#   'neighborhood': 'Dedham'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'liquor_store',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '350 Patriot Place, Foxborough',
#   'neighborhood': 'Foxborough'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '45 Beacon Street, Somerville',
#   'neighborhood': 'Somerville'},
#  {'name': 'Walmart',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '254 Lowell Road, Hudson',
#   'neighborhood': 'Hudson'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '51 Middlesex Turnpike, Burlington',
#   'neighborhood': 'Burlington'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '51 Austin Street, Charlestown',
#   'neighborhood': 'Charlestown'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '1028 Beacon Street, Brookline',
#   'neighborhood': 'Brookline'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '170 Great Road, Bedford',
#   'neighborhood': 'Bedford'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '1427 Massachusetts Avenue, Arlington',
#   'neighborhood': 'Arlington'},
#  {'name': 'Roche Bros. Acton',
#   'types': ['supermarket',
#    'florist',
#    'bakery',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '387 Massachusetts Avenue, Acton',
#   'neighborhood': 'Acton'},
#  {'name': 'C-Mart Supermarket',
#   'types': ['supermarket',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '50 Herald Street, Boston',
#   'neighborhood': 'Boston'},
#  {'name': 'The Fresh Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '11 Essington Drive, Hingham',
#   'neighborhood': 'Hingham'},
#  {'name': 'Roche Bros. Wellesley',
#   'types': ['supermarket',
#    'florist',
#    'meal_delivery',
#    'bakery',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '184 Linden Street, Wellesley',
#   'neighborhood': 'Wellesley'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '145 Great Road, Acton',
#   'neighborhood': 'Acton'},
#  {'name': 'Roche Bros. Natick',
#   'types': ['supermarket',
#    'florist',
#    'bakery',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '150 West Central Street, Natick',
#   'neighborhood': 'Natick'},
#  {'name': 'Walmart',
#   'types': ['supermarket',
#    'department_store',
#    'grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '777 Brockton Avenue, Abington',
#   'neighborhood': 'Abington'},
#  {'name': 'Market Basket',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '227 Highland Avenue, Salem',
#   'neighborhood': 'Salem'},
#  {'name': 'Walmart Supercenter',
#   'types': ['department_store',
#    'supermarket',
#    'grocery_or_supermarket',
#    'electronics_store',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '36 Paramount Drive, Raynham',
#   'neighborhood': 'Raynham'},
#  {'name': "Trader Joe's",
#   'types': ['grocery_or_supermarket',
#    'florist',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 2,
#   'address': '77 Boston Turnpike, Shrewsbury',
#   'neighborhood': 'Shrewsbury'},
#  {'name': 'Whole Foods Market',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'health',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 3,
#   'address': '255 Hartford Avenue, Bellingham',
#   'neighborhood': 'Bellingham'},
#  {'name': 'Walmart Supercenter',
#   'types': ['department_store',
#    'supermarket',
#    'grocery_or_supermarket',
#    'electronics_store',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '1470 South Washington Street, North Attleborough',
#   'neighborhood': 'North Attleborough'},
#  {'name': 'Market Basket',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 'N/A',
#   'address': '274 Hartford Avenue, Bellingham',
#   'neighborhood': 'Bellingham'},
#  {'name': 'ALDI',
#   'types': ['grocery_or_supermarket',
#    'supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'price_level': 1,
#   'address': '60 Newport Avenue, Rumford',
#   'neighborhood': 'Rumford'}]

# %%
len(supermarket)
# Out:
# 68
