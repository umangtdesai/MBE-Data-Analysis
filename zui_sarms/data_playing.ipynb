# %% [markdown]
# # Playing around with data
#
# ## Food Inspection

# %%
from senpai.food_insp import download_csv

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("./food_insp.csv", dtype=object)

# %%
df.columns.values
# Out:
# array(['businessname', 'dbaname', 'legalowner', 'namelast', 'namefirst',
#        'licenseno', 'issdttm', 'expdttm', 'licstatus', 'licensecat',
#        'descript', 'result', 'resultdttm', 'violation', 'viollevel',
#        'violdesc', 'violdttm', 'violstatus', 'statusdate', 'comments',
#        'address', 'city', 'state', 'zip', 'property_id', 'location'],
#       dtype=object)

# %%
# Project to select only the column we wants
DF = df[["businessname", "licenseno", "violstatus", "address", "city", "state", "zip", "property_id", "location"]]

# Remove the row which has an empty value [x for row in table for x in row if x] 
DF = DF.dropna()

# Select all the Fail violations 
DF = DF[DF["violstatus"] == "Fail"]

# Count violations per restaurant
VC = DF.groupby("licenseno").count()

DF_R = DF.set_index("licenseno")[["businessname", "address", "city", "state", "zip", "location"]]
DF_R["violation_count"] = VC["violstatus"]
DF_R = DF_R.drop_duplicates()

DF_R["_id"] = DF_R.index.values
DF_R["location"] = DF_R["location"].map(parse_coor)

# %%
DF_R.loc["87059","location"]
# Out:
# [42.27859, -71.11944]

# %%
def parse_coor(s):
    """
    Parse the string to tuple of coordinate
    In the format of (lat, long)
    """
    
    lat, long = s.split(", ")
    lat = lat[1:]
    long = long[:-1]
    lat = float(lat)
    long = float(long)
    
    return [lat, long]

# %%
DF_R.to_dict(orient="record")
# Out:
# [{'businessname': '100 Percent Delicia Food',
#   'address': '635   Hyde Park AVE',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.27859, -71.11944],
#   'violation_count': 91,
#   '_id': '87059'},
#  {'businessname': '1000 Degrees Pizza',
#   'address': '55   Court ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.359227, -71.058878],
#   'violation_count': 7,
#   '_id': '313440'},
#  {'businessname': '1000 Washington Cafe',
#   'address': '1000   Washington ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.345875, -71.064496],
#   'violation_count': 8,
#   '_id': '34789'},
#  {'businessname': '125 Nashua St. Cafe (MGH)',
#   'address': '125  Nashua St',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02114',
#   'location': [42.36783, -71.06495],
#   'violation_count': 1,
#   '_id': '130844'},
#  {'businessname': '150 Boylston St. Dining Room @ Emerson College',
#   'address': '150   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.352266, -71.066497],
#   'violation_count': 21,
#   '_id': '29381'},
#  {'businessname': '20TH CENTRY BOWLING LANES',
#   'address': '1231   Hyde Park AVE',
#   'city': 'Hyde Park',
#   'state': 'MA',
#   'zip': '02136',
#   'location': [42.25682, -71.12411],
#   'violation_count': 21,
#   '_id': '18671'},
#  {'businessname': '21 ST. AMENDMENT',
#   'address': '150   Bowdoin ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.358336, -71.062581],
#   'violation_count': 137,
#   '_id': '19863'},
#  {'businessname': '224 BOSTON',
#   'address': '224   Boston ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02125',
#   'location': [42.322272, -71.060848],
#   'violation_count': 6,
#   '_id': '370784'},
#  {'businessname': '224 BOSTON STREET',
#   'address': '224   Boston ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02125',
#   'location': [42.322272, -71.060848],
#   'violation_count': 70,
#   '_id': '21328'},
#  {'businessname': '24 SEVEN',
#   'address': '655   Warren ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02121',
#   'location': [42.309649, -71.082981],
#   'violation_count': 63,
#   '_id': '21272'},
#  {'businessname': '28 DEGREES',
#   'address': '1   Appleton ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.346725, -71.069653],
#   'violation_count': 29,
#   '_id': '24047'},
#  {'businessname': '29 Newbury Street',
#   'address': '29   Newbury ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.35247, -71.07277],
#   'violation_count': 86,
#   '_id': '18754'},
#  {'businessname': '2nd Cup Cafe',
#   'address': '101   Brighton AVE',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.353081, -71.130624],
#   'violation_count': 17,
#   '_id': '26681'},
#  {'businessname': "3 C's Cleveland Cir. Conv.",
#   'address': '358   Chestnut Hill AVE',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.33677, -71.15139],
#   'violation_count': 6,
#   '_id': '201794'},
#  {'businessname': "3 J's Auto Sales & Service Co.",
#   'address': '869   River ST',
#   'city': 'Hyde Park',
#   'state': 'MA',
#   'zip': '02136',
#   'location': [42.26238, -71.1091],
#   'violation_count': 1,
#   '_id': '25964'},
#  {'businessname': '3 SCOOPS',
#   'address': '403   Washington ST',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.349293, -71.155079],
#   'violation_count': 1,
#   '_id': '23966'},
#  {'businessname': '303 Cafe',
#   'address': '303   Sumner ST',
#   'city': 'East Boston',
#   'state': 'MA',
#   'zip': '02128',
#   'location': [42.367407, -71.036713],
#   'violation_count': 48,
#   '_id': '27924'},
#  {'businessname': '320 Cafe',
#   'address': '314   Spring ST',
#   'city': 'West Roxbury',
#   'state': 'MA',
#   'zip': '02132',
#   'location': [42.271712, -71.17211],
#   'violation_count': 15,
#   '_id': '344670'},
#  {'businessname': '33 RESTAURANT & LOUNGE',
#   'address': '33   Stanhope ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.348524, -71.073158],
#   'violation_count': 21,
#   '_id': '22164'},
#  {'businessname': '4 Quarter Plus Bargain Center',
#   'address': '884A   Morton ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.281039, -71.084666],
#   'violation_count': 6,
#   '_id': '75193'},
#  {'businessname': '49 Social',
#   'address': '49  Temple Pl',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.35493, -71.061809],
#   'violation_count': 37,
#   '_id': '75153'},
#  {'businessname': '4M MARKET',
#   'address': '3114   Washington ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.31474, -71.09905],
#   'violation_count': 9,
#   '_id': '22060'},
#  {'businessname': "5 J's & M  Convenience Market",
#   'address': '1275   River ST',
#   'city': 'Hyde Park',
#   'state': 'MA',
#   'zip': '02136',
#   'location': [42.256072, -71.124361],
#   'violation_count': 14,
#   '_id': '308971'},
#  {'businessname': '5 Napkin Burger',
#   'address': '101  Huntington AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02199',
#   'location': [42.346865, -71.080632],
#   'violation_count': 123,
#   '_id': '74369'},
#  {'businessname': '556 Riverside Market',
#   'address': '556R  River ST',
#   'city': 'Mattapan',
#   'state': 'MA',
#   'zip': '02126',
#   'location': [42.266618, -71.095978],
#   'violation_count': 18,
#   '_id': '171161'},
#  {'businessname': '68 Chinese Fast Food',
#   'address': '48   Winter ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.355863, -71.061898],
#   'violation_count': 67,
#   '_id': '20591'},
#  {'businessname': '7 - Eleven No. 37491A',
#   'address': '684   Centre ST',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.311843, -71.114001],
#   'violation_count': 32,
#   '_id': '75776'},
#  {'businessname': '7 Pond Coffee Bar',
#   'address': '597   Centre ST',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.3149, -71.11427],
#   'violation_count': 7,
#   '_id': '98134'},
#  {'businessname': '7 Star St. Bistro/Astro Diner/Rozzie Ramen',
#   'address': '153   Belgrade AVE',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.286425, -71.136969],
#   'violation_count': 53,
#   '_id': '75599'},
#  {'businessname': '73 Cafe',
#   'address': '73   Tremont ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.35788, -71.06082],
#   'violation_count': 19,
#   '_id': '68356'},
#  {'businessname': '75 CHESTNUT',
#   'address': '75   Chestnut ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.356898, -71.070971],
#   'violation_count': 50,
#   '_id': '20638'},
#  {'businessname': '75 STATE STREET LOBBY SHOP',
#   'address': '75  State ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02109',
#   'location': [42.35863, -71.05534],
#   'violation_count': 2,
#   '_id': '23114'},
#  {'businessname': '753 South',
#   'address': '749   South ST',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.28716, -71.12912],
#   'violation_count': 17,
#   '_id': '332241'},
#  {'businessname': '88 SUPERMARKET',
#   'address': '50   Herald ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.34644, -71.06499],
#   'violation_count': 51,
#   '_id': '19720'},
#  {'businessname': '89 Broad Street',
#   'address': '89   Broad ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02110',
#   'location': [42.35744, -71.05316],
#   'violation_count': 29,
#   '_id': '200737'},
#  {'businessname': '89C Crepe & Ice Cream',
#   'address': '75   Harvard AVE',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.353624, -71.132412],
#   'violation_count': 5,
#   '_id': '302293'},
#  {'businessname': '99 LOBBY SHOP',
#   'address': '99   High ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02110',
#   'location': [42.354245, -71.05484],
#   'violation_count': 6,
#   '_id': '22128'},
#  {'businessname': '99 RESTAURANT AND PUB',
#   'address': '29   Austin ST',
#   'city': 'Charlestown',
#   'state': 'MA',
#   'zip': '02129',
#   'location': [42.374884, -71.067065],
#   'violation_count': 100,
#   '_id': '19530'},
#  {'businessname': 'A & C Food Market',
#   'address': '67   Woodrow AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.288, -71.08097],
#   'violation_count': 5,
#   '_id': '81268'},
#  {'businessname': 'A & C LIQUORS',
#   'address': '7   Edgewater DR',
#   'city': 'Mattapan',
#   'state': 'MA',
#   'zip': '02126',
#   'location': [42.266828, -71.09489],
#   'violation_count': 5,
#   '_id': '19365'},
#  {'businessname': 'A & N PIZZA',
#   'address': '1409   Centre ST',
#   'city': 'West Roxbury',
#   'state': 'MA',
#   'zip': '02132',
#   'location': [42.29413, -71.13674],
#   'violation_count': 51,
#   '_id': '23626'},
#  {'businessname': 'A @ Time',
#   'address': '417   Cambridge ST',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.355123, -71.134062],
#   'violation_count': 2,
#   '_id': '77645'},
#  {'businessname': 'A @ Time',
#   'address': '417   Cambridge ST',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.355123, -71.134062],
#   'violation_count': 23,
#   '_id': '83847'},
#  {'businessname': 'A C Farm Market',
#   'address': '1429   Dorchester AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.302302, -71.0598],
#   'violation_count': 149,
#   '_id': '74325'},
#  {'businessname': 'A J Wright No. 175',
#   'address': '60   Everett ST',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.35654, -71.13923],
#   'violation_count': 2,
#   '_id': '25528'},
#  {'businessname': "A K's Kitchen",
#   'address': '1234  Columbus AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.329343, -71.095804],
#   'violation_count': 31,
#   '_id': '31973'},
#  {'businessname': "A K's Take Out",
#   'address': '305   D ST',
#   'city': 'South Boston',
#   'state': 'MA',
#   'zip': '02127',
#   'location': [42.339955, -71.049226],
#   'violation_count': 59,
#   '_id': '28862'},
#  {'businessname': "A K's Take Out & Delivery",
#   'address': '1427   Tremont ST',
#   'city': 'Mission Hill',
#   'state': 'MA',
#   'zip': '02120',
#   'location': [42.331858, -71.096333],
#   'violation_count': 271,
#   '_id': '28531'},
#  {'businessname': 'A.J. VARIETY',
#   'address': '7   Bowdoin ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.29935, -71.073098],
#   'violation_count': 3,
#   '_id': '22990'},
#  {'businessname': 'A Sweet Place',
#   'address': '1514   Dorchester AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.29902, -71.06036],
#   'violation_count': 1,
#   '_id': '78290'},
#  {'businessname': 'A Taste of Jamaica',
#   'address': '124   Harvard ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.29643, -71.07965],
#   'violation_count': 5,
#   '_id': '75537'},
#  {'businessname': 'A Time To Taste',
#   'address': '181   Devonshire ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02110',
#   'location': [42.356053, -71.057513],
#   'violation_count': 2,
#   '_id': '77513'},
#  {'businessname': 'A-1 Convenience',
#   'address': '285 A   Main ST',
#   'city': 'Charlestown',
#   'state': 'MA',
#   'zip': '02129',
#   'location': [42.37766, -71.066886],
#   'violation_count': 43,
#   '_id': '28193'},
#  {'businessname': 'A1 Mini Mart',
#   'address': '390   Dorchester ST',
#   'city': 'South Boston',
#   'state': 'MA',
#   'zip': '02127',
#   'location': [42.32975, -71.05639],
#   'violation_count': 16,
#   '_id': '173082'},
#  {'businessname': 'AA Market',
#   'address': '138  South ST',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.30516, -71.11445],
#   'violation_count': 9,
#   '_id': '144097'},
#  {'businessname': 'AAA GROCERY',
#   'address': '181   Washington ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02121',
#   'location': [42.303377, -71.078771],
#   'violation_count': 16,
#   '_id': '126307'},
#  {'businessname': 'AAA GROCERY',
#   'address': '181   Washington ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02121',
#   'location': [42.303377, -71.078771],
#   'violation_count': 5,
#   '_id': '345536'},
#  {'businessname': "Abbott's Frozen Custard",
#   'address': '362  Washington St',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.348955, -71.153641],
#   'violation_count': 9,
#   '_id': '74489'},
#  {'businessname': 'Abby Lane',
#   'address': '253   Tremont ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.35044, -71.06535],
#   'violation_count': 65,
#   '_id': '79241'},
#  {'businessname': "ABE & LOUIE'S",
#   'address': '793   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.34924, -71.0816],
#   'violation_count': 24,
#   '_id': '20939'},
#  {'businessname': "ABE & LOUIE'S",
#   'address': '793   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.34924, -71.0816],
#   'violation_count': 62,
#   '_id': '75242'},
#  {'businessname': 'Abreu Market',
#   'address': '180   Hyde Park AVE',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.294741, -71.116732],
#   'violation_count': 6,
#   '_id': '174408'},
#  {'businessname': 'Abyssinia Market',
#   'address': '1127   Harrison AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.330446, -71.08203],
#   'violation_count': 16,
#   '_id': '134743'},
#  {'businessname': 'Academy Market',
#   'address': '1588  Columbus AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.321557, -71.098071],
#   'violation_count': 127,
#   '_id': '31731'},
#  {'businessname': 'ACADEMY MARKET',
#   'address': '1588  Columbus AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.321557, -71.098071],
#   'violation_count': 16,
#   '_id': '22414'},
#  {'businessname': 'ACE Sushi @ Stop & Shop No. 429',
#   'address': '1100  Massachusetts AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02125',
#   'location': [42.3263, -71.06527],
#   'violation_count': 15,
#   '_id': '141538'},
#  {'businessname': 'Acougue Sabor Brasil',
#   'address': '233   London ST',
#   'city': 'East Boston',
#   'state': 'MA',
#   'zip': '02128',
#   'location': [42.37589, -71.03578],
#   'violation_count': 95,
#   '_id': '25944'},
#  {'businessname': 'Adam Market',
#   'address': '116   Blackstone ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02109',
#   'location': [42.361798, -71.056711],
#   'violation_count': 26,
#   '_id': '31881'},
#  {'businessname': 'Adams B & B',
#   'address': '12   Edgerly RD',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02115',
#   'location': [42.34606, -71.08786],
#   'violation_count': 2,
#   '_id': '21988'},
#  {'businessname': 'Adams Convenience',
#   'address': '295   Adams ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.299128, -71.05811],
#   'violation_count': 1,
#   '_id': '123701'},
#  {'businessname': 'ADAMS CONVENIENCE STORE',
#   'address': '114   Blackstone ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02109',
#   'location': [42.361782, -71.056763],
#   'violation_count': 3,
#   '_id': '139414'},
#  {'businessname': 'ADAMS CONVENIENCE STORE',
#   'address': '295   Adams ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.299128, -71.05811],
#   'violation_count': 26,
#   '_id': '23893'},
#  {'businessname': 'Adams Fish Mkt',
#   'address': '781   Adams ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.283394, -71.055886],
#   'violation_count': 36,
#   '_id': '18021'},
#  {'businessname': 'Adams Market',
#   'address': '365   Adams ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.297038, -71.056791],
#   'violation_count': 33,
#   '_id': '22154'},
#  {'businessname': 'Adams Village Shell',
#   'address': '761   Adams ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.28405, -71.05587],
#   'violation_count': 5,
#   '_id': '24760'},
#  {'businessname': 'Addis Red Sea',
#   'address': '540   Tremont ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.34405, -71.07097],
#   'violation_count': 71,
#   '_id': '18526'},
#  {'businessname': 'Advance Auto Parts No. 8636',
#   'address': '676   Morton ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.28515, -71.09268],
#   'violation_count': 16,
#   '_id': '27683'},
#  {'businessname': 'Advance Auto Parts No. 8639',
#   'address': '4185   Washington ST',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.28753, -71.1273],
#   'violation_count': 18,
#   '_id': '27684'},
#  {'businessname': 'Advance Auto Parts No. 8649',
#   'address': '373   Cambridge ST',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.355492, -71.133277],
#   'violation_count': 7,
#   '_id': '27679'},
#  {'businessname': 'ADVENT SCHOOL',
#   'address': '17   Brimmer ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.35822, -71.07204],
#   'violation_count': 8,
#   '_id': '20915'},
#  {'businessname': 'AFC Sushi @ Emerson College',
#   'address': '120  Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.352219, -71.065735],
#   'violation_count': 1,
#   '_id': '385773'},
#  {'businessname': "AFC Sushi @ Shaw's No. 586",
#   'address': '4   River ST',
#   'city': 'Mattapan',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.271841, -71.069999],
#   'violation_count': 45,
#   '_id': '126794'},
#  {'businessname': 'AFC SUSHI @ STARMARKET 4572',
#   'address': '370  Western AVE',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.361095, -71.137831],
#   'violation_count': 42,
#   '_id': '21946'},
#  {'businessname': 'ALEX PIZZA',
#   'address': '1252   Washington ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.342301, -71.067378],
#   'violation_count': 77,
#   '_id': '24310'},
#  {'businessname': 'AFC Sushi @ Suffolk University',
#   'address': '41   Temple ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02114',
#   'location': [42.36, -71.06383],
#   'violation_count': 19,
#   '_id': '34037'},
#  {'businessname': 'AFC Sushi @ Walgreens No. 15390',
#   'address': '10   School ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.357327, -71.058968],
#   'violation_count': 22,
#   '_id': '90461'},
#  {'businessname': 'AFC SUSHI @SIMMONS COLLEGE',
#   'address': '300   Fenway  ',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02115',
#   'location': [42.33931, -71.09996],
#   'violation_count': 14,
#   '_id': '73444'},
#  {'businessname': "Agoro's Pizza Bar & Grill",
#   'address': '356   Chestnut Hill AVE',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.336824, -71.151471],
#   'violation_count': 15,
#   '_id': '303536'},
#  {'businessname': 'AGUADILLA MARKET',
#   'address': '664   Tremont ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.34141, -71.07586],
#   'violation_count': 7,
#   '_id': '24243'},
#  {'businessname': 'Aguasvivas Market',
#   'address': '920   Morton ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.280686, -71.082955],
#   'violation_count': 28,
#   '_id': '98124'},
#  {'businessname': 'Aislyn Meat Market',
#   'address': '71   Day ST',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.32459, -71.108306],
#   'violation_count': 30,
#   '_id': '26192'},
#  {'businessname': "AK's Takeout",
#   'address': '309   D ST',
#   'city': 'South Boston',
#   'state': 'MA',
#   'zip': '02127',
#   'location': [42.339981, -71.04924],
#   'violation_count': 56,
#   '_id': '330021'},
#  {'businessname': 'AL CAPONE',
#   'address': '80   Summer ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02110',
#   'location': [42.35402, -71.05813],
#   'violation_count': 147,
#   '_id': '22813'},
#  {'businessname': 'AL DENTE RISTORANTE',
#   'address': '109   Salem ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02113',
#   'location': [42.36421, -71.05536],
#   'violation_count': 122,
#   '_id': '19660'},
#  {'businessname': 'Al Prime Energy',
#   'address': '497   Gallivan BLVD',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.2824, -71.05611],
#   'violation_count': 7,
#   '_id': '80573'},
#  {'businessname': 'Albany Sandwich Shop',
#   'address': '471   Albany ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.33974, -71.065],
#   'violation_count': 1,
#   '_id': '27663'},
#  {'businessname': 'ALBA PRODUCE',
#   'address': '18   Parmenter ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02113',
#   'location': [42.36382, -71.05508],
#   'violation_count': 8,
#   '_id': '21026'},
#  {'businessname': 'Al-Barah Market',
#   'address': '114   Blackstone ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02109',
#   'location': [42.361782, -71.056763],
#   'violation_count': 2,
#   '_id': '67974'},
#  {'businessname': 'Alberto Market',
#   'address': '1112   Blue Hill AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.2863, -71.09041],
#   'violation_count': 37,
#   '_id': '121518'},
#  {'businessname': 'Alex Market VI',
#   'address': '466   Talbot AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.289007, -71.066548],
#   'violation_count': 32,
#   '_id': '201333'},
#  {'businessname': 'Alcove',
#   'address': '131  Beverly ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02114',
#   'location': [42.36703, -71.060086],
#   'violation_count': 8,
#   '_id': '346419'},
#  {'businessname': 'Alex Liquors',
#   'address': '23   Corinth ST',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.286183, -71.130048],
#   'violation_count': 1,
#   '_id': '91075'},
#  {'businessname': 'Alex Market',
#   'address': '316  Talbot AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.2906, -71.07286],
#   'violation_count': 65,
#   '_id': '29784'},
#  {'businessname': "Alexander's Wine & Spirit",
#   'address': '755   Gallivan BLVD',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.283819, -71.044839],
#   'violation_count': 28,
#   '_id': '22887'},
#  {'businessname': "Alex's Liquor Inc.",
#   'address': '569   American Legion HWY',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.287133, -71.108605],
#   'violation_count': 12,
#   '_id': '140185'},
#  {'businessname': "Alex's Market III  Inc.",
#   'address': '2825   Washington ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.321289, -71.092736],
#   'violation_count': 53,
#   '_id': '77881'},
#  {'businessname': "ALFREDO'S ITALIAN KITCHEN",
#   'address': '243   Dorchester ST',
#   'city': 'South Boston',
#   'state': 'MA',
#   'zip': '02127',
#   'location': [42.332855, -71.051318],
#   'violation_count': 60,
#   '_id': '23175'},
#  {'businessname': "ALEX'S MARKET IV",
#   'address': '466   Talbot AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.289007, -71.066548],
#   'violation_count': 18,
#   '_id': '112710'},
#  {'businessname': "ALEX'S PIZZA",
#   'address': '580   Dorchester AVE',
#   'city': 'South Boston',
#   'state': 'MA',
#   'zip': '02127',
#   'location': [42.32994, -71.056778],
#   'violation_count': 56,
#   '_id': '23264'},
#  {'businessname': 'Alfa Auto Fuel',
#   'address': '4139   Washington ST',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.28925, -71.12559],
#   'violation_count': 2,
#   '_id': '23542'},
#  {'businessname': "ALFREDO'S",
#   'address': '229   Brighton AVE',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.353679, -71.135669],
#   'violation_count': 83,
#   '_id': '22825'},
#  {'businessname': 'ALI ROTI RESTAURANT',
#   'address': '1035   Tremont ST',
#   'city': 'Mission Hill',
#   'state': 'MA',
#   'zip': '02120',
#   'location': [42.33666, -71.08563],
#   'violation_count': 156,
#   '_id': '20778'},
#  {'businessname': 'Alibi',
#   'address': '215   Charles ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02114',
#   'location': [42.36203, -71.070362],
#   'violation_count': 58,
#   '_id': '77887'},
#  {'businessname': "Alipio's Market",
#   'address': '353   Chelsea ST',
#   'city': 'East Boston',
#   'state': 'MA',
#   'zip': '02128',
#   'location': [42.37828, -71.02873],
#   'violation_count': 11,
#   '_id': '159570'},
#  {'businessname': 'All American Water',
#   'address': '1320   Dorchester AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.30564, -71.05866],
#   'violation_count': 6,
#   '_id': '86865'},
#  {'businessname': 'All American Water',
#   'address': '3   Neponset AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.297, -71.05634],
#   'violation_count': 27,
#   '_id': '157991'},
#  {'businessname': 'All Star Pizza Bar',
#   'address': '204   Cambridge ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02114',
#   'location': [42.360955, -71.065859],
#   'violation_count': 38,
#   '_id': '308806'},
#  {'businessname': 'ALLIS ROTI + MEAT MARKET',
#   'address': '1188   Blue Hill AVE',
#   'city': 'Mattapan',
#   'state': 'MA',
#   'zip': '02126',
#   'location': [42.28377, -71.09129],
#   'violation_count': 87,
#   '_id': '18944'},
#  {'businessname': 'Allandale Farm',
#   'address': '259   Allandale ST',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.302221, -71.139365],
#   'violation_count': 32,
#   '_id': '18032'},
#  {'businessname': 'Allston Cafe',
#   'address': '155   Brighton AVE',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.3532, -71.131939],
#   'violation_count': 24,
#   '_id': '19269'},
#  {'businessname': 'Allston Convenience Store',
#   'address': '163   Allston ST',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.347954, -71.138155],
#   'violation_count': 22,
#   '_id': '27591'},
#  {'businessname': 'Allston Diner',
#   'address': '417   Cambridge ST',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.355123, -71.134062],
#   'violation_count': 41,
#   '_id': '78169'},
#  {'businessname': 'Almany Market',
#   'address': '1053   Tremont ST',
#   'city': 'Mission Hill',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.336513, -71.085998],
#   'violation_count': 30,
#   '_id': '158675'},
#  {'businessname': "Al's Bottled Liquors",
#   'address': '226 W Broadway ',
#   'city': 'South Boston',
#   'state': 'MA',
#   'zip': '02127',
#   'location': [42.340048, -71.052291],
#   'violation_count': 41,
#   '_id': '18850'},
#  {'businessname': "Al's South St. Express",
#   'address': '179   Essex ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.352051, -71.057585],
#   'violation_count': 20,
#   '_id': '28744'},
#  {'businessname': 'Alumni 1',
#   'address': '2597   Beacon ST',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.336249, -71.166434],
#   'violation_count': 8,
#   '_id': '68154'},
#  {'businessname': 'Alumni 2',
#   'address': '2597   Beacon ST',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.336249, -71.166434],
#   'violation_count': 6,
#   '_id': '68156'},
#  {'businessname': 'Alumni 3',
#   'address': '2597   Beacon ST',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.336249, -71.166434],
#   'violation_count': 7,
#   '_id': '68158'},
#  {'businessname': 'Alumni 4',
#   'address': '2597   Beacon ST',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.336249, -71.166434],
#   'violation_count': 1,
#   '_id': '68160'},
#  {'businessname': 'Alumni 5',
#   'address': '2597   Beacon ST',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.336249, -71.166434],
#   'violation_count': 2,
#   '_id': '68162'},
#  {'businessname': "Alvarado's Family Market",
#   'address': '1512   Dorchester AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.299109, -71.060321],
#   'violation_count': 2,
#   '_id': '333248'},
#  {'businessname': 'Al-Wadi Restaurant',
#   'address': '1249   VFW PKWY',
#   'city': 'West Roxbury',
#   'state': 'MA',
#   'zip': '02132',
#   'location': [42.27724, -71.17261],
#   'violation_count': 186,
#   '_id': '68660'},
#  {'businessname': 'Amateras',
#   'address': '112  South ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.350987, -71.057143],
#   'violation_count': 3,
#   '_id': '140294'},
#  {'businessname': 'AMC Theatres Boston Common 19',
#   'address': '175   Tremont ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.35315, -71.06403],
#   'violation_count': 165,
#   '_id': '21804'},
#  {'businessname': 'American Bakers',
#   'address': '39   First AVE',
#   'city': 'Charlestown',
#   'state': 'MA',
#   'zip': '02129',
#   'location': [42.37556, -71.053919],
#   'violation_count': 58,
#   '_id': '29000'},
#  {'businessname': "Amelia's Taqueria",
#   'address': '309   Huntington AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02115',
#   'location': [42.341196, -71.087659],
#   'violation_count': 37,
#   '_id': '137353'},
#  {'businessname': "Amelia's Taqueria",
#   'address': '180   Brighton AVE',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.353014, -71.133631],
#   'violation_count': 40,
#   '_id': '90271'},
#  {'businessname': "Amelia's Taqueria III",
#   'address': '1936   Beacon ST',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.336353, -71.149931],
#   'violation_count': 20,
#   '_id': '333294'},
#  {'businessname': 'American Legion Market',
#   'address': '569   American Legion HWY',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.287133, -71.108605],
#   'violation_count': 2,
#   '_id': '73652'},
#  {'businessname': 'American Nut & Chocolate',
#   'address': '121   Newmarket SQ',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.330596, -71.066966],
#   'violation_count': 5,
#   '_id': '32379'},
#  {'businessname': 'Americano Espresso Bar',
#   'address': '155   Meridian ST',
#   'city': 'East Boston',
#   'state': 'MA',
#   'zip': '02128',
#   'location': [42.373853, -71.038885],
#   'violation_count': 12,
#   '_id': '24849'},
#  {'businessname': 'Americas Food Basket',
#   'address': '920   Cummins HWY',
#   'city': 'Mattapan',
#   'state': 'MA',
#   'zip': '02126',
#   'location': [42.26794, -71.09447],
#   'violation_count': 114,
#   '_id': '91514'},
#  {'businessname': "AMERICA'S FOOD BASKET",
#   'address': '576   Washington ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.291523, -71.071458],
#   'violation_count': 182,
#   '_id': '74772'},
#  {'businessname': 'Amici',
#   'address': '111 N Washington ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02113',
#   'location': [42.365582, -71.058131],
#   'violation_count': 14,
#   '_id': '83699'},
#  {'businessname': 'Amorino',
#   'address': '249   Newbury ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.349755, -71.082793],
#   'violation_count': 10,
#   '_id': '129539'},
#  {'businessname': 'Amory Restaurant',
#   'address': '224   Amory ST',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.316306, -71.103188],
#   'violation_count': 22,
#   '_id': '22054'},
#  {'businessname': 'Amory Restaurant',
#   'address': '222   Amory ST',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.316388, -71.103161],
#   'violation_count': 48,
#   '_id': '32930'},
#  {'businessname': 'Amory Restaurant Inc.',
#   'address': '222   Amory ST',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.316388, -71.103161],
#   'violation_count': 2,
#   '_id': '75100'},
#  {'businessname': 'AMSTERDAM CAFE',
#   'address': '483 E Broadway ',
#   'city': 'South Boston',
#   'state': 'MA',
#   'zip': '02127',
#   'location': [42.335274, -71.04559],
#   'violation_count': 41,
#   '_id': '86558'},
#  {'businessname': 'AMSTERDAM CAFE',
#   'address': '483 E Broadway ',
#   'city': 'South Boston',
#   'state': 'MA',
#   'zip': '02127',
#   'location': [42.335274, -71.04559],
#   'violation_count': 36,
#   '_id': '24532'},
#  {'businessname': "Amy's Wrap N'Roll",
#   'address': '400   Brookline AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02115',
#   'location': [42.33863, -71.107191],
#   'violation_count': 41,
#   '_id': '37238'},
#  {'businessname': 'AN TAIN',
#   'address': '31   India ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02110',
#   'location': [42.35823, -71.05315],
#   'violation_count': 96,
#   '_id': '21024'},
#  {'businessname': 'ANDALE! MEXICAN GRILL',
#   'address': '125  Summer ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.353033, -71.057556],
#   'violation_count': 37,
#   '_id': '22905'},
#  {'businessname': "Andre's Cafe",
#   'address': '809   Harrison AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.335864, -71.074203],
#   'violation_count': 39,
#   '_id': '140634'},
#  {'businessname': 'Andrade Market',
#   'address': '93   Burrell ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.32363, -71.0682],
#   'violation_count': 3,
#   '_id': '33725'},
#  {'businessname': 'Andrea Mini Market',
#   'address': '2   Fairmount AVE',
#   'city': 'Hyde Park',
#   'state': 'MA',
#   'zip': '02136',
#   'location': [42.25584, -71.12089],
#   'violation_count': 19,
#   '_id': '33222'},
#  {'businessname': "Andre's Cafe",
#   'address': '811   Harrison AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.335768, -71.074298],
#   'violation_count': 56,
#   '_id': '37295'},
#  {'businessname': "ANDRE'S CAFE",
#   'address': '811   Harrison AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.335768, -71.074298],
#   'violation_count': 49,
#   '_id': '23044'},
#  {'businessname': 'ANDREW SQUARE HOUSE OF PIZZA',
#   'address': '395  Dorchester ST',
#   'city': 'South Boston',
#   'state': 'MA',
#   'zip': '02127',
#   'location': [42.33003, -71.05655],
#   'violation_count': 52,
#   '_id': '19813'},
#  {'businessname': 'Andrew Square Market',
#   'address': '605   Dorchester AVE',
#   'city': 'South Boston',
#   'state': 'MA',
#   'zip': '02127',
#   'location': [42.328926, -71.057118],
#   'violation_count': 7,
#   '_id': '20048'},
#  {'businessname': "Angela's Cafe",
#   'address': '131   Lexington ST',
#   'city': 'East Boston',
#   'state': 'MA',
#   'zip': '02128',
#   'location': [42.37853, -71.035],
#   'violation_count': 100,
#   '_id': '27539'},
#  {'businessname': "Angel's Market",
#   'address': '501   Washington ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.29415, -71.07213],
#   'violation_count': 52,
#   '_id': '74821'},
#  {'businessname': "Angela's Cafe II",
#   'address': '1012   Bennington ST',
#   'city': 'East Boston',
#   'state': 'MA',
#   'zip': '02128',
#   'location': [42.387115, -71.006309],
#   'violation_count': 23,
#   '_id': '166852'},
#  {'businessname': 'ANH HONG RESTAURANT  LLC',
#   'address': '291   Adams ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.299183, -71.05818],
#   'violation_count': 149,
#   '_id': '23490'},
#  {'businessname': 'AQUITAINE',
#   'address': '569   Tremont ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.343801, -71.07235],
#   'violation_count': 338,
#   '_id': '20803'},
#  {'businessname': 'Anna Hand Cut Donuts',
#   'address': '2056   Centre ST',
#   'city': 'West Roxbury',
#   'state': 'MA',
#   'zip': '02132',
#   'location': [42.280014, -71.158191],
#   'violation_count': 67,
#   '_id': '18298'},
#  {'businessname': "Annabelle's Restaurant",
#   'address': '1300  Hyde Park AVE',
#   'city': 'Hyde Park',
#   'state': 'MA',
#   'zip': '02136',
#   'location': [42.254144, -71.124084],
#   'violation_count': 25,
#   '_id': '74420'},
#  {'businessname': "Anna's Cafe",
#   'address': '267   Medford ST',
#   'city': 'Charlestown',
#   'state': 'MA',
#   'zip': '02129',
#   'location': [42.38129, -71.061549],
#   'violation_count': 4,
#   '_id': '135886'},
#  {'businessname': "Anna's Taqueria",
#   'address': '800   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02199',
#   'location': [42.347296, -71.081457],
#   'violation_count': 6,
#   '_id': '338302'},
#  {'businessname': "Anna's Taqueria",
#   'address': '242   Cambridge ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02114',
#   'location': [42.36093, -71.0671],
#   'violation_count': 65,
#   '_id': '30122'},
#  {'businessname': 'Another Cup? Coffee House',
#   'address': '1   Nassau ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.348583, -71.062975],
#   'violation_count': 7,
#   '_id': '78515'},
#  {'businessname': 'ANOULD DISCOUNT & RETAIL STORE',
#   'address': '1145   Blue Hill AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.285394, -71.091371],
#   'violation_count': 5,
#   '_id': '19325'},
#  {'businessname': 'Anshur Restauruant',
#   'address': '291   Roxbury ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.33041, -71.0943],
#   'violation_count': 366,
#   '_id': '31241'},
#  {'businessname': "ANTHONY'S CAFE",
#   'address': '252   Commercial ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02109',
#   'location': [42.36399, -71.05137],
#   'violation_count': 75,
#   '_id': '19977'},
#  {'businessname': "Anthony's Market II",
#   'address': '317   Meridian ST',
#   'city': 'East Boston',
#   'state': 'MA',
#   'zip': '02128',
#   'location': [42.377599, -71.038994],
#   'violation_count': 6,
#   '_id': '142480'},
#  {'businessname': 'ANTICO FORNO',
#   'address': '93   Salem ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02113',
#   'location': [42.363742, -71.055591],
#   'violation_count': 135,
#   '_id': '20296'},
#  {'businessname': 'Antoinette Variety Store',
#   'address': '1600   Blue Hill AVE',
#   'city': 'Mattapan',
#   'state': 'MA',
#   'zip': '02126',
#   'location': [42.26928, -71.09335],
#   'violation_count': 53,
#   '_id': '86624'},
#  {'businessname': 'Antojitos & Panaderia Chapina',
#   'address': '299   Hancock ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02125',
#   'location': [42.308205, -71.058731],
#   'violation_count': 80,
#   '_id': '28832'},
#  {'businessname': 'Antojitos Dominicanos Y Mas',
#   'address': '379   Blue Hill AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02121',
#   'location': [42.31175, -71.08108],
#   'violation_count': 10,
#   '_id': '119294'},
#  {'businessname': 'Antojitos Panaderia Mi Guatemala INC.',
#   'address': '299   Hancock ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02125',
#   'location': [42.308104, -71.058789],
#   'violation_count': 12,
#   '_id': '79253'},
#  {'businessname': 'Antonio Cafe',
#   'address': '554A   Dudley ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02125',
#   'location': [42.3213, -71.07199],
#   'violation_count': 25,
#   '_id': '29466'},
#  {'businessname': 'Antonios Bacaro',
#   'address': '1   Fairmount AVE',
#   'city': 'Hyde Park',
#   'state': 'MA',
#   'zip': '02136',
#   'location': [42.25558, -71.12118],
#   'violation_count': 4,
#   '_id': '146011'},
#  {'businessname': "Antonio's Hi-Fi",
#   'address': '1508   Dorchester AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.29929, -71.06025],
#   'violation_count': 60,
#   '_id': '134056'},
#  {'businessname': "ANTONIO'S ITALIANO CUCINA",
#   'address': '286   Cambridge ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02114',
#   'location': [42.360951, -71.06816],
#   'violation_count': 63,
#   '_id': '19837'},
#  {'businessname': "APPLEBEE'S NEIGHBORHOOD GRILL & BAR",
#   'address': '11A  Allstate RD',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02125',
#   'location': [42.326047, -71.063611],
#   'violation_count': 59,
#   '_id': '77404'},
#  {'businessname': 'Appleton Bakery & Cafe',
#   'address': '75   Dartmouth ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.345259, -71.074714],
#   'violation_count': 58,
#   '_id': '86765'},
#  {'businessname': 'Appleton Bakery Cafe',
#   'address': '123   Appleton ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.345292, -71.07463],
#   'violation_count': 15,
#   '_id': '20774'},
#  {'businessname': 'Appleton Cafe',
#   'address': '123   Appleton ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.345292, -71.07463],
#   'violation_count': 49,
#   '_id': '341093'},
#  {'businessname': 'Appleton Cafe',
#   'address': '123   Appleton ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.345292, -71.07463],
#   'violation_count': 11,
#   '_id': '75280'},
#  {'businessname': 'ARAMARK @ BROWNE BROS.HARRIMAN',
#   'address': '40   Water ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02109',
#   'location': [42.357737, -71.05678],
#   'violation_count': 15,
#   '_id': '24106'},
#  {'businessname': 'ARAMARK @ SULLIVAN & WORCESTER',
#   'address': '1   Post Office SQ',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02109',
#   'location': [42.356797, -71.054981],
#   'violation_count': 17,
#   '_id': '22391'},
#  {'businessname': 'Aramark at Houghton Mifflin',
#   'address': '222   Berkeley ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.35084, -71.07311],
#   'violation_count': 94,
#   '_id': '24693'},
#  {'businessname': 'ARAMARK CORPORATION FOOD COURT',
#   'address': '415  Summer ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02210',
#   'location': [42.344449, -71.044821],
#   'violation_count': 22,
#   '_id': '23194'},
#  {'businessname': 'Arberto Market',
#   'address': '220   Columbia RD',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02121',
#   'location': [42.30759, -71.07629],
#   'violation_count': 18,
#   '_id': '29256'},
#  {'businessname': 'Arboretum Grill',
#   'address': '4021   Washington ST',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.29201, -71.12244],
#   'violation_count': 14,
#   '_id': '29989'},
#  {'businessname': 'Arboretum Grill',
#   'address': '4021   Washington ST',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.29201, -71.12244],
#   'violation_count': 133,
#   '_id': '77254'},
#  {'businessname': 'Arbri Caffe',
#   'address': '146   Belgrade AVE',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.286122, -71.136731],
#   'violation_count': 10,
#   '_id': '34614'},
#  {'businessname': 'ARC',
#   'address': '835   Beacon ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02115',
#   'location': [42.347012, -71.102881],
#   'violation_count': 45,
#   '_id': '22896'},
#  {'businessname': 'Archdale Liquors  Inc.',
#   'address': '3999   Washington ST',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.29279, -71.12165],
#   'violation_count': 18,
#   '_id': '25850'},
#  {'businessname': "ARCHIE'S NEW YORK DELI",
#   'address': '93   Arch ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02110',
#   'location': [42.355042, -71.059128],
#   'violation_count': 94,
#   '_id': '19907'},
#  {'businessname': "Archie's Place",
#   'address': '227   Washington ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.357884, -71.058215],
#   'violation_count': 41,
#   '_id': '67723'},
#  {'businessname': "Archie's Place",
#   'address': '227   Washington ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.357884, -71.058215],
#   'violation_count': 45,
#   '_id': '87069'},
#  {'businessname': 'Ariana Restaurant',
#   'address': '127   Brighton AV',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.353242, -71.131192],
#   'violation_count': 24,
#   '_id': '67790'},
#  {'businessname': 'Aristo Cafe',
#   'address': '90  State St',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02109',
#   'location': [42.35925, -71.05534],
#   'violation_count': 17,
#   '_id': '37119'},
#  {'businessname': 'Arizona B B Q',
#   'address': '2360   Washington ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.32937, -71.08446],
#   'violation_count': 306,
#   '_id': '29252'},
#  {'businessname': 'ARTU',
#   'address': '6   Prince ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02113',
#   'location': [42.36411, -71.05372],
#   'violation_count': 96,
#   '_id': '19399'},
#  {'businessname': 'Asia Wok',
#   'address': '44  Harvard AVE',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.354462, -71.13227],
#   'violation_count': 82,
#   '_id': '28681'},
#  {'businessname': "Arthur's Sunoco",
#   'address': '70   River ST',
#   'city': 'Mattapan',
#   'state': 'MA',
#   'zip': '02126',
#   'location': [42.27127, -71.07302],
#   'violation_count': 1,
#   '_id': '19998'},
#  {'businessname': 'Article 24',
#   'address': '458   Western AVE',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.36195, -71.14221],
#   'violation_count': 17,
#   '_id': '155639'},
#  {'businessname': 'ARTU',
#   'address': '89   Charles ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02114',
#   'location': [42.35859, -71.07049],
#   'violation_count': 89,
#   '_id': '20046'},
#  {'businessname': 'Arya Trattoria',
#   'address': '253   Hanover ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02113',
#   'location': [42.363223, -71.054789],
#   'violation_count': 6,
#   '_id': '86940'},
#  {'businessname': 'ASAKI',
#   'address': '418  Market ST',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.349342, -71.153159],
#   'violation_count': 36,
#   '_id': '22153'},
#  {'businessname': 'Ashburton Cafe',
#   'address': '1   Ashburton PL',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02114',
#   'location': [42.359276, -71.062359],
#   'violation_count': 148,
#   '_id': '25883'},
#  {'businessname': "ASHLEY'S BREAKFAST SHOPPE",
#   'address': '260  Bowdoin ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02125',
#   'location': [42.30678, -71.0667],
#   'violation_count': 102,
#   '_id': '20237'},
#  {'businessname': 'Ashmont Convenience Store',
#   'address': '1996   Dorchester AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.2829, -71.06489],
#   'violation_count': 26,
#   '_id': '76483'},
#  {'businessname': 'ASHMONT GRILL',
#   'address': '555   Talbot AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.286091, -71.064728],
#   'violation_count': 89,
#   '_id': '23991'},
#  {'businessname': 'Asian B B Q and Grill',
#   'address': '48   Winter ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.355863, -71.061898],
#   'violation_count': 13,
#   '_id': '67915'},
#  {'businessname': 'ASIAN THAI EATERY INC.',
#   'address': '1064   River ST',
#   'city': 'Hyde Park',
#   'state': 'MA',
#   'zip': '02136',
#   'location': [42.258784, -71.117741],
#   'violation_count': 75,
#   '_id': '23727'},
#  {'businessname': 'Asian House',
#   'address': '99  Cambridge ST',
#   'city': 'Charlestown',
#   'state': 'MA',
#   'zip': '02129',
#   'location': [42.38254, -71.0792],
#   'violation_count': 41,
#   '_id': '112706'},
#  {'businessname': 'ASIAN PACIFIC SEAFOOD TRADING',
#   'address': '216   Harrison AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.347964, -71.062808],
#   'violation_count': 32,
#   '_id': '24302'},
#  {'businessname': 'Asian Thai Eatery',
#   'address': '1064   River ST',
#   'city': 'Hyde Park',
#   'state': 'MA',
#   'zip': '02136',
#   'location': [42.258784, -71.117741],
#   'violation_count': 15,
#   '_id': '353239'},
#  {'businessname': 'ASSAGGIO RESTAURANT',
#   'address': '25   Prince ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02113',
#   'location': [42.364563, -71.05416],
#   'violation_count': 44,
#   '_id': '20360'},
#  {'businessname': 'Assembly on 2',
#   'address': '100   Summer ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02110',
#   'location': [42.353633, -71.057366],
#   'violation_count': 4,
#   '_id': '345414'},
#  {'businessname': 'ATLANTIC FISH COMPANY',
#   'address': '761   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.34935, -71.08121],
#   'violation_count': 25,
#   '_id': '21188'},
#  {'businessname': 'ATLANTIC FISH COMPANY',
#   'address': '761   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.34935, -71.08121],
#   'violation_count': 101,
#   '_id': '75240'},
#  {'businessname': 'ATRIUM CAFE & CONFERENCE CTR.',
#   'address': '1   Waverly PL',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.352467, -71.056269],
#   'violation_count': 6,
#   '_id': '23160'},
# ...
#   'violation_count': 7,
#   '_id': '17603'},
#  {'businessname': 'Cinque Cento',
#   'address': '500   Harrison AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.3419, -71.06592],
#   'violation_count': 19,
#   '_id': '77970'},
#  {'businessname': 'Cirque Du Soleil',
#   'address': '100  Northern AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02210',
#   'location': [42.352856, -71.043074],
#   'violation_count': 5,
#   '_id': '30856'},
#  {'businessname': 'Cirque Du Soleil',
#   'address': '6  Tide ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02210',
#   'location': [42.345809, -71.031808],
#   'violation_count': 4,
#   '_id': '79344'},
#  {'businessname': 'Cirque Du Soleil - Spectrum Catering',
#   'address': '525  William F McClellan HWY',
#   'city': 'East Boston',
#   'state': 'MA',
#   'zip': '02128',
#   'location': [42.395173, -71.000092],
#   'violation_count': 1,
#   '_id': '68529'},
#  {'businessname': 'Citizen Public House & Oyster Bar',
#   'address': '1310   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02215',
#   'location': [42.344213, -71.097954],
#   'violation_count': 87,
#   '_id': '68543'},
#  {'businessname': 'City Produce',
#   'address': '231   Harrison AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.347471, -71.063018],
#   'violation_count': 13,
#   '_id': '127935'},
#  {'businessname': 'Citra A Fresh Cafe',
#   'address': '221   Longwood AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02115',
#   'location': [42.33724, -71.10217],
#   'violation_count': 25,
#   '_id': '80224'},
#  {'businessname': 'Citrus & Salt',
#   'address': '142   Berkeley ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.348822, -71.072098],
#   'violation_count': 100,
#   '_id': '97090'},
#  {'businessname': 'CITY CONVENIENCE',
#   'address': '86   Massachusetts AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02115',
#   'location': [42.348689, -71.088169],
#   'violation_count': 1,
#   '_id': '20614'},
#  {'businessname': 'City Fresh Foods',
#   'address': '1   Harborside DR',
#   'city': 'East Boston',
#   'state': 'MA',
#   'zip': '02128',
#   'location': [42.363408, -71.025698],
#   'violation_count': 2,
#   '_id': '28510'},
#  {'businessname': 'City Fresh Foods @ Roxbury Comm. College',
#   'address': '1234  Columbus AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.329343, -71.095804],
#   'violation_count': 17,
#   '_id': '27884'},
#  {'businessname': 'city landing',
#   'address': '255   State ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02109',
#   'location': [42.359417, -71.051129],
#   'violation_count': 6,
#   '_id': '80315'},
#  {'businessname': 'City Produce',
#   'address': '231   Harrison AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.347471, -71.063018],
#   'violation_count': 6,
#   '_id': '160452'},
#  {'businessname': 'City Sports',
#   'address': '480   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02115',
#   'location': [42.350722, -71.073709],
#   'violation_count': 6,
#   '_id': '20377'},
#  {'businessname': 'City Sports',
#   'address': '1035   Commonwealth AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02215',
#   'location': [42.352262, -71.12196],
#   'violation_count': 4,
#   '_id': '20375'},
#  {'businessname': 'City Tap House',
#   'address': '374  Congress ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02210',
#   'location': [42.34993, -71.04741],
#   'violation_count': 8,
#   '_id': '163109'},
#  {'businessname': 'CJ Teriyaki & Seafood',
#   'address': '736   Blue Hill AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02121',
#   'location': [42.299726, -71.086059],
#   'violation_count': 4,
#   '_id': '34524'},
#  {'businessname': 'Clarendon Wine Co.',
#   'address': '561   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.350679, -71.076273],
#   'violation_count': 25,
#   '_id': '78381'},
#  {'businessname': 'Clarendon Wine Co.',
#   'address': '561   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.350679, -71.076273],
#   'violation_count': 5,
#   '_id': '18170'},
#  {'businessname': "CLARKE'S",
#   'address': '21   Merchants ROW',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02109',
#   'location': [42.359461, -71.05548],
#   'violation_count': 113,
#   '_id': '18796'},
#  {'businessname': "Clarke's at South Station",
#   'address': '640   Atlantic AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02110',
#   'location': [42.350021, -71.055941],
#   'violation_count': 27,
#   '_id': '19533'},
#  {'businessname': 'Claudia Market',
#   'address': '160   Humboldt AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.314634, -71.088069],
#   'violation_count': 2,
#   '_id': '20721'},
#  {'businessname': "Claudia's Market",
#   'address': '160   Humboldt AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.314634, -71.088069],
#   'violation_count': 10,
#   '_id': '67921'},
#  {'businessname': "CLERY'S",
#   'address': '331   Columbus AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.346117, -71.075191],
#   'violation_count': 190,
#   '_id': '20702'},
#  {'businessname': "Claudio's Market",
#   'address': '419   Bowdoin ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.31043, -71.06209],
#   'violation_count': 47,
#   '_id': '27600'},
#  {'businessname': 'Clay Pot Cafe',
#   'address': '74  Kneeland St',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.350475, -71.060383],
#   'violation_count': 39,
#   '_id': '91913'},
#  {'businessname': 'C-Mart Supermarket  Inc.',
#   'address': '680  Washington ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.351393, -71.062629],
#   'violation_count': 137,
#   '_id': '23209'},
#  {'businessname': 'Cleveland Circle Convenience',
#   'address': '358   Chestnut Hill AVE',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.33677, -71.15139],
#   'violation_count': 6,
#   '_id': '68343'},
#  {'businessname': 'CLINTON MARKET',
#   'address': '702   American Legion HWY',
#   'city': 'Roslindale',
#   'state': 'MA',
#   'zip': '02131',
#   'location': [42.283188, -71.112261],
#   'violation_count': 54,
#   '_id': '21449'},
#  {'businessname': 'Clipper Ship Wine & Spirits',
#   'address': '17   Maverick SQ',
#   'city': 'East Boston',
#   'state': 'MA',
#   'zip': '02128',
#   'location': [42.369029, -71.039179],
#   'violation_count': 14,
#   '_id': '18996'},
#  {'businessname': 'Clover',
#   'address': '27   School ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.357719, -71.05907],
#   'violation_count': 9,
#   '_id': '156345'},
#  {'businessname': 'Clover',
#   'address': '160   Federal ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02110',
#   'location': [42.354049, -71.055925],
#   'violation_count': 3,
#   '_id': '158462'},
#  {'businessname': 'Club Cafe',
#   'address': '209   Columbus AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.348549, -71.07237],
#   'violation_count': 74,
#   '_id': '18340'},
#  {'businessname': 'CLUB HOTEL BAR',
#   'address': '240   Mount Vernon ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02125',
#   'location': [42.319024, -71.045007],
#   'violation_count': 2,
#   '_id': '21131'},
#  {'businessname': 'Cluckit!',
#   'address': '782A   Tremont ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.33899, -71.08051],
#   'violation_count': 33,
#   '_id': '74726'},
#  {'businessname': 'C-Mart Herald Street',
#   'address': '50   Herald ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.34644, -71.06499],
#   'violation_count': 157,
#   '_id': '31218'},
#  {'businessname': 'C-MART II',
#   'address': '109   Lincoln ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02111',
#   'location': [42.35154, -71.05857],
#   'violation_count': 95,
#   '_id': '23172'},
#  {'businessname': 'Cobblestones',
#   'address': '227   Hanover ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02113',
#   'location': [42.362972, -71.055089],
#   'violation_count': 44,
#   '_id': '86647'},
#  {'businessname': 'Coco Leaf',
#   'address': '1480  Dorchester Av',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.30008, -71.05995],
#   'violation_count': 13,
#   '_id': '198089'},
#  {'businessname': 'Cocobeet',
#   'address': '100   City Hall PLZ',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02108',
#   'location': [42.359529, -71.05875],
#   'violation_count': 50,
#   '_id': '112739'},
#  {'businessname': "COCO'S",
#   'address': '3171   Washington ST',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.313471, -71.100829],
#   'violation_count': 22,
#   '_id': '78227'},
#  {'businessname': 'Code 10 Restaurant Cafe',
#   'address': '2 E Concord ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.33791, -71.07465],
#   'violation_count': 67,
#   '_id': '125523'},
#  {'businessname': 'Codman Square Market',
#   'address': '573   Washington ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.291634, -71.072],
#   'violation_count': 84,
#   '_id': '23268'},
#  {'businessname': 'Coffee Cafe',
#   'address': '200   Seaport BLVD',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02210',
#   'location': [42.35001, -71.04099],
#   'violation_count': 23,
#   '_id': '20030'},
#  {'businessname': 'Codman Square Market Corp.',
#   'address': '331   Centre ST',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.32287, -71.105],
#   'violation_count': 14,
#   '_id': '155779'},
#  {'businessname': 'Codman Square Pharmacy',
#   'address': '624   Washington ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.289848, -71.071251],
#   'violation_count': 1,
#   '_id': '19882'},
#  {'businessname': 'COFFEE SHOP',
#   'address': '11   Elkins ST',
#   'city': 'South Boston',
#   'state': 'MA',
#   'zip': '02127',
#   'location': [42.339353, -71.036129],
#   'violation_count': 30,
#   '_id': '18489'},
#  {'businessname': 'COLD STONE CREAMERY',
#   'address': '8   Park PLZ',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.351362, -71.06874],
#   'violation_count': 23,
#   '_id': '24379'},
#  {'businessname': 'Cold Stone Creamery',
#   'address': '800   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02199',
#   'location': [42.347296, -71.081457],
#   'violation_count': 31,
#   '_id': '141000'},
#  {'businessname': 'Cold Stone Creamery',
#   'address': '957   Commonwealth AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02215',
#   'location': [42.35191, -71.11889],
#   'violation_count': 3,
#   '_id': '27992'},
#  {'businessname': 'COLD STONE CREAMERY',
#   'address': '175   Cambridge ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02114',
#   'location': [42.362108, -71.065881],
#   'violation_count': 2,
#   '_id': '24418'},
#  {'businessname': 'COLD STONE CREAMERY',
#   'address': '470   Washington ST',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.3487, -71.15954],
#   'violation_count': 1,
#   '_id': '23915'},
#  {'businessname': 'Coldstone Creamery',
#   'address': '470   Washington ST',
#   'city': 'Brighton',
#   'state': 'MA',
#   'zip': '02135',
#   'location': [42.3487, -71.15954],
#   'violation_count': 11,
#   '_id': '24859'},
#  {'businessname': 'College Club',
#   'address': '44   Commonwealth AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.35273, -71.07335],
#   'violation_count': 36,
#   '_id': '18350'},
#  {'businessname': 'COLLEGE PIZZA',
#   'address': '50   Queensberry ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02215',
#   'location': [42.342574, -71.097279],
#   'violation_count': 70,
#   '_id': '93571'},
#  {'businessname': 'Colonnade Hotel',
#   'address': '120   Huntington AVE',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.34551, -71.08107],
#   'violation_count': 159,
#   '_id': '18614'},
#  {'businessname': 'COLLEGE PIZZA',
#   'address': '50   Queensberry ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02215',
#   'location': [42.342574, -71.097279],
#   'violation_count': 34,
#   '_id': '21569'},
#  {'businessname': 'COLOR',
#   'address': '166   Harvard AVE',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.351497, -71.131379],
#   'violation_count': 11,
#   '_id': '21910'},
#  {'businessname': 'Color Inc.',
#   'address': '800   Boylston ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02199',
#   'location': [42.347296, -71.081457],
#   'violation_count': 1,
#   '_id': '24630'},
#  {'businessname': 'Columbia Park Cafe @ Santander Bank',
#   'address': '2   William T Morrissey BLVD',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02125',
#   'location': [42.31943, -71.04927],
#   'violation_count': 48,
#   '_id': '80374'},
#  {'businessname': 'COLUMBIA RD. MARKET',
#   'address': '387   Columbia RD',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02125',
#   'location': [42.311028, -71.070128],
#   'violation_count': 100,
#   '_id': '21512'},
#  {'businessname': 'COLUMBUS CAFE & BAR',
#   'address': '535   Columbus AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02118',
#   'location': [42.341856, -71.08056],
#   'violation_count': 87,
#   '_id': '24064'},
#  {'businessname': 'COLUMBUS MARKET',
#   'address': '1909   Columbus AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.317086, -71.098498],
#   'violation_count': 33,
#   '_id': '21474'},
#  {'businessname': 'Columbus Market',
#   'address': '1909   Columbus AVE',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02119',
#   'location': [42.317091, -71.098495],
#   'violation_count': 7,
#   '_id': '57529'},
#  {'businessname': 'Comedy Connection @ The Wilbur Theater',
#   'address': '244   Tremont ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02116',
#   'location': [42.3507, -71.06467],
#   'violation_count': 30,
#   '_id': '30417'},
#  {'businessname': "Comella's",
#   'address': '1882  Centre ST',
#   'city': 'West Roxbury',
#   'state': 'MA',
#   'zip': '02132',
#   'location': [42.28567, -71.15548],
#   'violation_count': 180,
#   '_id': '24754'},
#  {'businessname': 'COMMON GROUND',
#   'address': '83   Harvard AV',
#   'city': 'Allston',
#   'state': 'MA',
#   'zip': '02134',
#   'location': [42.353503, -71.132378],
#   'violation_count': 62,
#   '_id': '77319'},
#  {'businessname': 'COMMON GROUND CAFE',
#   'address': '2243   Dorchester AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.273782, -71.06785],
#   'violation_count': 64,
#   '_id': '19917'},
#  {'businessname': 'Common Vines',
#   'address': '100   Summer ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02110',
#   'location': [42.353633, -71.057366],
#   'violation_count': 1,
#   '_id': '302883'},
#  {'businessname': 'Community Care Pharmacy',
#   'address': '2100   Dorchester AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.278028, -71.066046],
#   'violation_count': 3,
#   '_id': '149875'},
#  {'businessname': 'Community Convenience Store',
#   'address': '311   Geneva AVE',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02122',
#   'location': [42.303115, -71.071263],
#   'violation_count': 8,
#   '_id': '160869'},
#  {'businessname': 'Community Convenience Store',
#   'address': '44   Norfolk ST',
#   'city': 'Dorchester',
#   'state': 'MA',
#   'zip': '02124',
#   'location': [42.28904, -71.07317],
#   'violation_count': 25,
#   '_id': '167342'},
#  {'businessname': 'Community Workshop Inc.',
#   'address': '174   Portland ST',
#   'city': 'Boston',
#   'state': 'MA',
#   'zip': '02114',
#   'location': [42.364123, -71.061819],
#   'violation_count': 65,
#   '_id': '18746'},
#  {'businessname': 'Compadres Meat Market',
#   'address': '3101   Washington ST',
#   'city': 'Roxbury',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.31516, -71.09918],
#   'violation_count': 132,
#   '_id': '75938'},
#  {'businessname': 'COMPASS SCHOOL',
#   'address': '26   Sunnyside ST',
#   'city': 'Jamaica Plain',
#   'state': 'MA',
#   'zip': '02130',
#   'location': [42.323564, -71.107129],
#   'violation_count': 20,
#   '_id': '19650'},
#  ...]
