# %%
import requests
import json
import dml
import prov.model
import datetime
import uuid
from bs4 import BeautifulSoup as bs

# %%
contributor = 'mmao95_Dongyihe_weijiang_zhukk'
reads = []
writes = [contributor + '.famous_people']

# %% [markdown]
# ## exec

# %%
startTime = datetime.datetime.now()

# Set up the database connection.
client = dml.pymongo.MongoClient()
repo = client.repo
repo.authenticate(contributor, contributor)
# Out:
# True

# %%
doc = requests.get("https://www.50states.com/bio/mass.htm").text
soup = bs(doc)
names = [e.text for e in soup.select("#content b")]

# %%
list = []
for name in names:
    parts = name.split()
    obj = {
        'full_name': name,
        'first_name': parts[0],
        'last_name': parts[-1] if len(parts) > 1 else None,
        'middle_name': parts[1:-1] if len(parts) > 2 else None
    }
    list.append(obj)

# %%
repo.dropCollection('famous_people')
repo.createCollection('famous_people')
repo[writes[0]].insert_many(list)

# %%
repo[writes[0]].metadata({'complete': True})
print(repo[writes[0]].metadata())
[record for record in repo[writes[0]].find()]
# Out:
# {'_id': ObjectId('5c80360a1fcf2f448f372474'), 'complete': True}
# [{'_id': ObjectId('5c8036091fcf2f448f372438'),
#   'full_name': 'John Adams',
#   'first_name': 'John',
#   'last_name': 'Adams',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372439'),
#   'full_name': 'John Quincy Adams',
#   'first_name': 'John',
#   'last_name': 'Adams',
#   'middle_name': ['Quincy']},
#  {'_id': ObjectId('5c8036091fcf2f448f37243a'),
#   'full_name': 'Samuel Adams',
#   'first_name': 'Samuel',
#   'last_name': 'Adams',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f37243b'),
#   'full_name': 'Jack Albertson',
#   'first_name': 'Jack',
#   'last_name': 'Albertson',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f37243c'),
#   'full_name': 'Horatio Alger',
#   'first_name': 'Horatio',
#   'last_name': 'Alger',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f37243d'),
#   'full_name': 'Susan B. Anthony',
#   'first_name': 'Susan',
#   'last_name': 'Anthony',
#   'middle_name': ['B.']},
#  {'_id': ObjectId('5c8036091fcf2f448f37243e'),
#   'full_name': 'F. Lee Bailey',
#   'first_name': 'F.',
#   'last_name': 'Bailey',
#   'middle_name': ['Lee']},
#  {'_id': ObjectId('5c8036091fcf2f448f37243f'),
#   'full_name': 'Clara Barton',
#   'first_name': 'Clara',
#   'last_name': 'Barton',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372440'),
#   'full_name': 'Leonard Bernstein',
#   'first_name': 'Leonard',
#   'last_name': 'Bernstein',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372441'),
#   'full_name': 'Forrest M. Bird',
#   'first_name': 'Forrest',
#   'last_name': 'Bird',
#   'middle_name': ['M.']},
#  {'_id': ObjectId('5c8036091fcf2f448f372442'),
#   'full_name': 'Harold Stephen Black',
#   'first_name': 'Harold',
#   'last_name': 'Black',
#   'middle_name': ['Stephen']},
#  {'_id': ObjectId('5c8036091fcf2f448f372443'),
#   'full_name': 'Rachel Fuller Brown',
#   'first_name': 'Rachel',
#   'last_name': 'Brown',
#   'middle_name': ['Fuller']},
#  {'_id': ObjectId('5c8036091fcf2f448f372444'),
#   'full_name': 'William Cullen Bryant',
#   'first_name': 'William',
#   'last_name': 'Bryant',
#   'middle_name': ['Cullen']},
#  {'_id': ObjectId('5c8036091fcf2f448f372445'),
#   'full_name': 'Luther Burbank',
#   'first_name': 'Luther',
#   'last_name': 'Burbank',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372446'),
#   'full_name': 'George Bush',
#   'first_name': 'George',
#   'last_name': 'Bush',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372447'),
#   'full_name': 'John Chapman / Johnny Appleseed',
#   'first_name': 'John',
#   'last_name': 'Appleseed',
#   'middle_name': ['Chapman', '/', 'Johnny']},
#  {'_id': ObjectId('5c8036091fcf2f448f372448'),
#   'full_name': 'William D. Coolidge',
#   'first_name': 'William',
#   'last_name': 'Coolidge',
#   'middle_name': ['D.']},
#  {'_id': ObjectId('5c8036091fcf2f448f372449'),
#   'full_name': 'John Singleton Copley',
#   'first_name': 'John',
#   'last_name': 'Copley',
#   'middle_name': ['Singleton']},
#  {'_id': ObjectId('5c8036091fcf2f448f37244a'),
#   'full_name': 'E. E. Cummings',
#   'first_name': 'E.',
#   'last_name': 'Cummings',
#   'middle_name': ['E.']},
#  {'_id': ObjectId('5c8036091fcf2f448f37244b'),
#   'full_name': 'Bette Davis',
#   'first_name': 'Bette',
#   'last_name': 'Davis',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f37244c'),
#   'full_name': 'Cecil B. DeMille',
#   'first_name': 'Cecil',
#   'last_name': 'DeMille',
#   'middle_name': ['B.']},
#  {'_id': ObjectId('5c8036091fcf2f448f37244d'),
#   'full_name': 'Emily Dickinson',
#   'first_name': 'Emily',
#   'last_name': 'Dickinson',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f37244e'),
#   'full_name': 'Ralph Waldo Emerson',
#   'first_name': 'Ralph',
#   'last_name': 'Emerson',
#   'middle_name': ['Waldo']},
#  {'_id': ObjectId('5c8036091fcf2f448f37244f'),
#   'full_name': 'Brian Evans',
#   'first_name': 'Brian',
#   'last_name': 'Evans',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372450'),
#   'full_name': 'Ann Smith Franklin',
#   'first_name': 'Ann',
#   'last_name': 'Franklin',
#   'middle_name': ['Smith']},
#  {'_id': ObjectId('5c8036091fcf2f448f372451'),
#   'full_name': 'Benjamin Franklin',
#   'first_name': 'Benjamin',
#   'last_name': 'Franklin',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372452'),
#   'full_name': 'Buckminster Fuller',
#   'first_name': 'Buckminster',
#   'last_name': 'Fuller',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372453'),
#   'full_name': 'Robert Hutchings Goddard',
#   'first_name': 'Robert',
#   'last_name': 'Goddard',
#   'middle_name': ['Hutchings']},
#  {'_id': ObjectId('5c8036091fcf2f448f372454'),
#   'full_name': 'John Hancock',
#   'first_name': 'John',
#   'last_name': 'Hancock',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372455'),
#   'full_name': 'Nathaniel Hawthorne',
#   'first_name': 'Nathaniel',
#   'last_name': 'Hawthorne',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372456'),
#   'full_name': 'Oliver Wendell Holmes',
#   'first_name': 'Oliver',
#   'last_name': 'Holmes',
#   'middle_name': ['Wendell']},
#  {'_id': ObjectId('5c8036091fcf2f448f372457'),
#   'full_name': 'Oliver Wendell Holmes, Jr.',
#   'first_name': 'Oliver',
#   'last_name': 'Jr.',
#   'middle_name': ['Wendell', 'Holmes,']},
#  {'_id': ObjectId('5c8036091fcf2f448f372458'),
#   'full_name': 'Winslow Homer',
#   'first_name': 'Winslow',
#   'last_name': 'Homer',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372459'),
#   'full_name': 'Elias Howe',
#   'first_name': 'Elias',
#   'last_name': 'Howe',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f37245a'),
#   'full_name': 'Helen Hunt Jackson',
#   'first_name': 'Helen',
#   'last_name': 'Jackson',
#   'middle_name': ['Hunt']},
#  {'_id': ObjectId('5c8036091fcf2f448f37245b'),
#   'full_name': 'John F. Kennedy',
#   'first_name': 'John',
#   'last_name': 'Kennedy',
#   'middle_name': ['F.']},
#  {'_id': ObjectId('5c8036091fcf2f448f37245c'),
#   'full_name': 'Amy Lowell',
#   'first_name': 'Amy',
#   'last_name': 'Lowell',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f37245d'),
#   'full_name': 'Percival Lowell',
#   'first_name': 'Percival',
#   'last_name': 'Lowell',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f37245e'),
#   'full_name': 'James Russell Lowell',
#   'first_name': 'James',
#   'last_name': 'Lowell',
#   'middle_name': ['Russell']},
#  {'_id': ObjectId('5c8036091fcf2f448f37245f'),
#   'full_name': 'Robert Lowell',
#   'first_name': 'Robert',
#   'last_name': 'Lowell',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372460'),
#   'full_name': 'Horace Mann',
#   'first_name': 'Horace',
#   'last_name': 'Mann',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372461'),
#   'full_name': 'Cotton Mather',
#   'first_name': 'Cotton',
#   'last_name': 'Mather',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372462'),
#   'full_name': 'Sharon Christa McAuliffe',
#   'first_name': 'Sharon',
#   'last_name': 'McAuliffe',
#   'middle_name': ['Christa']},
#  {'_id': ObjectId('5c8036091fcf2f448f372463'),
#   'full_name': 'Samuel F. B. Morse',
#   'first_name': 'Samuel',
#   'last_name': 'Morse',
#   'middle_name': ['F.', 'B.']},
#  {'_id': ObjectId('5c8036091fcf2f448f372464'),
#   'full_name': 'Leonard Nemoy',
#   'first_name': 'Leonard',
#   'last_name': 'Nemoy',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372465'),
#   'full_name': 'Albert Pike',
#   'first_name': 'Albert',
#   'last_name': 'Pike',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372466'),
#   'full_name': 'Edgar Allan Poe',
#   'first_name': 'Edgar',
#   'last_name': 'Poe',
#   'middle_name': ['Allan']},
#  {'_id': ObjectId('5c8036091fcf2f448f372467'),
#   'full_name': 'Ella Raines',
#   'first_name': 'Ella',
#   'last_name': 'Raines',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372468'),
#   'full_name': 'Paul Revere',
#   'first_name': 'Paul',
#   'last_name': 'Revere',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372469'),
#   'full_name': 'Robert H. Rines',
#   'first_name': 'Robert',
#   'last_name': 'Rines',
#   'middle_name': ['H.']},
#  {'_id': ObjectId('5c8036091fcf2f448f37246a'),
#   'full_name': 'Dr. Seuss \xa0 Theodore Geisel',
#   'first_name': 'Dr.',
#   'last_name': 'Geisel',
#   'middle_name': ['Seuss', 'Theodore']},
#  {'_id': ObjectId('5c8036091fcf2f448f37246b'),
#   'full_name': 'Lucy Stone',
#   'first_name': 'Lucy',
#   'last_name': 'Stone',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f37246c'),
#   'full_name': 'Louis Henry Sullivan',
#   'first_name': 'Louis',
#   'last_name': 'Sullivan',
#   'middle_name': ['Henry']},
#  {'_id': ObjectId('5c8036091fcf2f448f37246d'),
#   'full_name': 'Henry David Thoreau',
#   'first_name': 'Henry',
#   'last_name': 'Thoreau',
#   'middle_name': ['David']},
#  {'_id': ObjectId('5c8036091fcf2f448f37246e'),
#   'full_name': 'Max Tishler',
#   'first_name': 'Max',
#   'last_name': 'Tishler',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f37246f'),
#   'full_name': 'James McNeill Whistler',
#   'first_name': 'James',
#   'last_name': 'Whistler',
#   'middle_name': ['McNeill']},
#  {'_id': ObjectId('5c8036091fcf2f448f372470'),
#   'full_name': 'Eli Whitney',
#   'first_name': 'Eli',
#   'last_name': 'Whitney',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372471'),
#   'full_name': 'John Greenleaf Whittier',
#   'first_name': 'John',
#   'last_name': 'Whittier',
#   'middle_name': ['Greenleaf']},
#  {'_id': ObjectId('5c8036091fcf2f448f372472'),
#   'full_name': 'Eli Whitney',
#   'first_name': 'Eli',
#   'last_name': 'Whitney',
#   'middle_name': None},
#  {'_id': ObjectId('5c8036091fcf2f448f372473'),
#   'full_name': 'Jo Dee Messina',
#   'first_name': 'Jo',
#   'last_name': 'Messina',
#   'middle_name': ['Dee']}]

# %%
repo.logout()
endTime = datetime.datetime.now()
{"start":startTime, "end":endTime}
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Database.logout() is deprecated
#   """Entry point for launching an IPython kernel.
# {'start': datetime.datetime(2019, 3, 6, 16, 5, 10, 889052),
#  'end': datetime.datetime(2019, 3, 6, 16, 5, 17, 533547)}

# %% [markdown]
# ## prov

# %%
doc = prov.model.ProvDocument()
startTime = None
endTime = None
client = dml.pymongo.MongoClient()
repo = client.repo
repo.authenticate(contributor, contributor)

doc.add_namespace('alg', 'http://datamechanics.io/algorithm/') # The scripts are in <folder>#<filename> format.
doc.add_namespace('dat', 'http://datamechanics.io/data/') # The data sets are in <user>#<collection> format.
doc.add_namespace('ont', 'http://datamechanics.io/ontology#') # 'Extension', 'DataResource', 'DataSet', 'Retrieval', 'Query', or 'Computation'.
doc.add_namespace('log', 'http://datamechanics.io/log/') # The event log.
doc.add_namespace('bdp', 'https://www.50states.com/bio/mass.htm')

this_script = doc.agent('alg:'+contributor+'#famous_people', {prov.model.PROV_TYPE:prov.model.PROV['SoftwareAgent'], 'ont:Extension':'py'})
resource = doc.entity('bdp:wc8w-nujj', {'prov:label':'311, Service Requests', prov.model.PROV_TYPE:'ont:DataResource', 'ont:Extension':'json'})
get_names = doc.activity('log:uuid'+str(uuid.uuid4()), startTime, endTime)
doc.wasAssociatedWith(get_names, this_script)
doc.usage(get_names, resource, startTime, None,
    {prov.model.PROV_TYPE:'ont:Retrieval',
    'ont:Computation':'Data cleaning'
    }
)

fp = doc.entity('dat:'+contributor+'#famous_people', {prov.model.PROV_LABEL:'Famous People', prov.model.PROV_TYPE:'ont:DataSet'})
doc.wasAttributedTo(fp, this_script)
doc.wasGeneratedBy(fp, get_names, endTime)
doc.wasDerivedFrom(fp, resource, get_names, get_names, get_names)

repo.logout()
doc
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:29: DeprecationWarning: Database.logout() is deprecated

# %%
print(doc.get_provn())
print(json.dumps(json.loads(doc.serialize()), indent=4))
# Out:
# document
#   prefix alg <http://datamechanics.io/algorithm/>
#   prefix dat <http://datamechanics.io/data/>
#   prefix ont <http://datamechanics.io/ontology#>
#   prefix log <http://datamechanics.io/log/>
#   prefix bdp <https://www.50states.com/bio/mass.htm>
#
#   agent(alg:mmao95_Dongyihe_weijiang_zhukk#famous_people, [prov:type='prov:SoftwareAgent', ont:Extension="py"])
#   entity(bdp:wc8w-nujj, [prov:label="311, Service Requests", prov:type="ont:DataResource", ont:Extension="json"])
#   activity(log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb, -, -)
#   wasAssociatedWith(log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb, alg:mmao95_Dongyihe_weijiang_zhukk#famous_people, -)
#   used(log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb, bdp:wc8w-nujj, -, [prov:type="ont:Retrieval", ont:Computation="Data cleaning"])
#   entity(dat:mmao95_Dongyihe_weijiang_zhukk#famous_people, [prov:label="Famous People", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:mmao95_Dongyihe_weijiang_zhukk#famous_people, alg:mmao95_Dongyihe_weijiang_zhukk#famous_people)
#   wasGeneratedBy(dat:mmao95_Dongyihe_weijiang_zhukk#famous_people, log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb, -)
#   wasDerivedFrom(dat:mmao95_Dongyihe_weijiang_zhukk#famous_people, bdp:wc8w-nujj, log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb, log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb, log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb)
# endDocument
# {
#     "prefix": {
#         "alg": "http://datamechanics.io/algorithm/",
#         "dat": "http://datamechanics.io/data/",
#         "ont": "http://datamechanics.io/ontology#",
#         "log": "http://datamechanics.io/log/",
#         "bdp": "https://www.50states.com/bio/mass.htm"
#     },
#     "agent": {
#         "alg:mmao95_Dongyihe_weijiang_zhukk#famous_people": {
#             "prov:type": {
#                 "$": "prov:SoftwareAgent",
#                 "type": "prov:QUALIFIED_NAME"
#             },
#             "ont:Extension": "py"
#         }
#     },
#     "entity": {
#         "bdp:wc8w-nujj": {
#             "prov:label": "311, Service Requests",
#             "prov:type": "ont:DataResource",
#             "ont:Extension": "json"
#         },
#         "dat:mmao95_Dongyihe_weijiang_zhukk#famous_people": {
#             "prov:label": "Famous People",
#             "prov:type": "ont:DataSet"
#         }
#     },
#     "activity": {
#         "log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb": {}
#     },
#     "wasAssociatedWith": {
#         "_:id1": {
#             "prov:activity": "log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb",
#             "prov:agent": "alg:mmao95_Dongyihe_weijiang_zhukk#famous_people"
#         }
#     },
#     "used": {
#         "_:id2": {
#             "prov:activity": "log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb",
#             "prov:entity": "bdp:wc8w-nujj",
#             "prov:type": "ont:Retrieval",
#             "ont:Computation": "Data cleaning"
#         }
#     },
#     "wasAttributedTo": {
#         "_:id3": {
#             "prov:entity": "dat:mmao95_Dongyihe_weijiang_zhukk#famous_people",
#             "prov:agent": "alg:mmao95_Dongyihe_weijiang_zhukk#famous_people"
#         }
#     },
#     "wasGeneratedBy": {
#         "_:id4": {
#             "prov:entity": "dat:mmao95_Dongyihe_weijiang_zhukk#famous_people",
#             "prov:activity": "log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb"
#         }
#     },
#     "wasDerivedFrom": {
#         "_:id5": {
#             "prov:generatedEntity": "dat:mmao95_Dongyihe_weijiang_zhukk#famous_people",
#             "prov:usedEntity": "bdp:wc8w-nujj",
#             "prov:activity": "log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb",
#             "prov:generation": "log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb",
#             "prov:usage": "log:uuide2575f89-f744-4fe5-9902-d1d92e7034fb"
#         }
#     }
# }
